# %%
import meep as mp
from meep import mpb
import numpy as np
import matplotlib.pyplot as plt
import time as time


def eigs_PCs(Px, Py, kx, ky, N_max, flag, Polarflag, r1, r2, Si_eps):
    kx_ = kx/(2*np.pi)
    ky_ = ky/(2*np.pi)
    res = 32

    geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1),
                                  basis1=mp.Vector3(1, 0),
                                  basis2=mp.Vector3(0.5, np.sqrt(3) / 2)
                                  )
    k_points = [mp.cartesian_to_reciprocal(mp.Vector3(kx_, ky_), geometry_lattice)]
    geometry = [mp.Cylinder(r1, center=mp.Vector3(0, 0), material=mp.Medium(index=1)),
                mp.Cylinder(r2, center=mp.Vector3(1 / 3, 1 / 3), material=mp.Medium(index=1))]
    ms = mpb.ModeSolver(
        geometry=geometry,
        geometry_lattice=geometry_lattice,
        default_material=mp.Medium(epsilon=Si_eps),
        k_points=k_points,
        resolution=res,
        num_bands=N_max
    )

    fields = []

    def get_efields(ms, band):
        fields.append(ms.get_efield(band, bloch_phase=False))

    def get_hfields(ms, band):
        fields.append(ms.get_hfield(band, bloch_phase=False))

    if Polarflag:
        ms.run_te(mpb.output_at_kpoint(k_points[0], mpb.fix_hfield_phase, get_hfields))
        eps = ms.get_mu()
        eps_te = ms.get_epsilon()
    else:
        ms.run_tm(mpb.output_at_kpoint(k_points[0], mpb.fix_efield_phase, get_efields))
        eps = ms.get_epsilon()

    freqss = ms.all_freqs

    converted_eps = eps.T
    converted = []
    for f in fields:
        # 三个点这个语法就是前面的若干项都省略不写
        f = f[..., 0, 2]
        # f.shape: [nx, ny, nz, 3]，前面3个是网格，第4个参数从0到2是表示Ex Ey Ez
        converted.append(f)
   

    return freqss.flatten()*2*np.pi/Px, converted, np.reshape(np.array(converted), (N_max, -1)).T, np.array(converted_eps).flatten(), eps_te.T
    #返回的3个值分别是频率，场，和eps




# Valley chen number 
do_chern = True  # do Chern Number Calc
do_band = False  # do Band Structure Calc
Pxg = 1  # lattice constant along x
Pyg = 1  # lattice constant along y
N_sam = 10  # Brillouin sampling points ***
N_max = 2  # maximum band number ***
np.set_printoptions(precision=3, suppress=True)

Polarflag = 1  # 极化方式，0，TM极化；1，TE极化

shifted = 0.0
Nkxg = 250
Nkyg = 1
Pkxg = (4 * np.pi ) / Pxg / np.sqrt(3)
Pkyg = (4 * np.pi ) / Pyg / np.sqrt(3)
deltakxg = Pkxg / Nkxg
deltakyg = deltakxg
NK = Nkxg * Nkyg
kcx = np.zeros((NK, 4))
kcy = np.zeros((NK, 4))
# initialized
fieldTot = np.zeros(N_max)
ChernNumber = np.zeros(N_max)
ChernNumber_1 = np.zeros(N_max)
ChernNumber_r = np.zeros(N_max)
fieldtemp = np.zeros(N_max, dtype=complex)
N_Lband = 1
N_Hband = 2

# calculate the curveture
if do_chern:
    time_s = time.time()
    fields_cur = np.zeros((Nkxg, N_max))
    neiji = np.zeros((Nkxg, N_max), dtype=complex)
    fields = []
    rr1 = 181/385/2
    rr2 = 181/385/2
    eps_si = 12
    #fields_cur = np.zeros((Nkxg, N_max))
    for m in range(Nkxg+1):
        for n in range(Nkyg+1): #平均伟Nkyg,实际边界有Nkyg+1个点
            print('Calculating', m * (Nkyg+1) + n + 1, 'of', (Nkxg/2+1) * (Nkyg+1), '...')
            omega, f, field_temp, eps_arr, eps = eigs_PCs(Pxg, Pyg,
                                                          # valley photonic crystal K Path
                                                    # left part1 from negative
                                                  (m  - Nkxg/2 +0.5) * deltakxg * np.sqrt(3), # 扫描平行四边形Kx
                                                  (n - 0.5 ) * deltakyg, # 扫描Ky，要键入kx的1/2
                                                  N_max, 0, Polarflag, rr1, rr2, eps_si)
            fields.append(field_temp)

    

    for m in range(Nkxg):
        for n in range(Nkyg):#这里不能是Nkyg+1，因为最右侧和最底部的边不能包括进来画网格
            field1 = fields[m*(Nkyg+1)+n] #将平行四边形分割成若干小网格，每个网格的四个顶点,=把field又排列一遍
            field4 = fields[m*(Nkyg+1)+n+1]
            field3 = fields[(m+1)*(Nkyg+1)+n+1]
            field2 = fields[(m+1)*(Nkyg+1)+n]

            for mm in range(N_max): #对每一个能带计算陈数
                temp = field1[:, mm].conj().T * eps_arr @ field2[:, mm] #一行乘以一列变成一个数
                fieldtemp[mm] = temp / np.abs(temp)
                temp = field2[:, mm].conj().T * eps_arr @ field3[:, mm]
                fieldtemp[mm] *= temp / np.abs(temp) #这里是把前面的值再乘新值
                temp = field3[:, mm].conj().T * eps_arr @ field4[:, mm]
                fieldtemp[mm] *= temp / np.abs(temp)
                temp = field4[:, mm].conj().T * eps_arr @ field1[:, mm]
                fieldtemp[mm] *= temp / np.abs(temp)
                neiji [m, mm] = fieldtemp[mm]
                fields_cur[m, mm] = -np.imag(np.log(fieldtemp[mm]))/(deltakxg**2*np.sqrt(3))
            

 
    print('Elapsed:', time.time() - time_s)
    
    plt.plot(fields_cur[:, 0]*(2*np.pi)**2)
    plt.show()
# Out:
# Calculating 1 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.996, -0.5000000000000001, 0.0>
# elapsed time for initialization: 0.033440351486206055
# solve_kpoint (-0.996,-0.5,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 0.9430813451671951 (197.681% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.1529654428294564 (144.176% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1195153661697503 (24.5522% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 55.2727%)
#     iteration    4: trace = 0.1154038200856195 (3.50039% change)
#     switching back to exact line minimization
#     iteration    5: trace = 0.1144259003629681 (0.850995% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 67.8767%)
#     iteration    6: trace = 0.1143081575306441 (0.102952% change)
#     iteration    7: trace = 0.11427316083491 (0.0306208% change)
#     iteration    8: trace = 0.114269054563006 (0.00359345% change)
#     iteration    9: trace = 0.1142680342802507 (0.000892882% change)
#     iteration   10: trace = 0.114267820276284 (0.000187283% change)
#     iteration   11: trace = 0.114267773922787 (4.05657e-05% change)
#     iteration   12: trace = 0.1142677596400414 (1.24994e-05% change)
#     iteration   13: trace = 0.114267757187595 (2.14623e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.996, -0.5, 0, 0.996003, 0.217181, 0.259037
# elapsed time for k point: 0.0333251953125
# Fixing h-field (band 1) phase by -0.303812 + -0.952732i; max ampl. = 1.31283
# Fixing h-field (band 2) phase by -0.402015 + -0.915633i; max ampl. = 2.18465
# total elapsed time for run: 0.0689549446105957
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 2 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.996, -0.4960000000000001, 0.0>
# elapsed time for initialization: 0.01845407485961914
# solve_kpoint (-0.996,-0.496,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 0.9430404673340542 (197.681% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.1524699601213623 (144.329% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1194195604339078 (24.3116% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 73.3691%)
#     iteration    4: trace = 0.1153931347331718 (3.42948% change)
#     iteration    5: trace = 0.1144254882948846 (0.842096% change)
#     iteration    6: trace = 0.1143091544272786 (0.10172% change)
#     iteration    7: trace = 0.1142736754178489 (0.0310426% change)
#     iteration    8: trace = 0.1142692758744012 (0.00385008% change)
#     iteration    9: trace = 0.1142681292728355 (0.00100343% change)
#     iteration   10: trace = 0.1142678748652764 (0.000222641% change)
#     iteration   11: trace = 0.1142678146175141 (5.2725e-05% change)
#     iteration   12: trace = 0.1142677975118993 (1.49698e-05% change)
#     iteration   13: trace = 0.1142677947679559 (2.40133e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.996, -0.496, 0, 0.996003, 0.217181, 0.259037
# elapsed time for k point: 0.03810572624206543
# Fixing h-field (band 1) phase by -0.376295 + -0.9265i; max ampl. = 1.3128
# Fixing h-field (band 2) phase by -0.430514 + -0.902584i; max ampl. = 2.18466
# total elapsed time for run: 0.06049966812133789
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 3 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.988, -0.4960000000000001, 0.0>
# elapsed time for initialization: 0.027151107788085938
# solve_kpoint (-0.988,-0.496,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 0.9423968136560916 (197.683% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.153248531797324 (144.052% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1196226511478435 (24.646% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 94.5082%)
#     iteration    4: trace = 0.1154600714382564 (3.54137% change)
#     iteration    5: trace = 0.1144666346271741 (0.864133% change)
#     iteration    6: trace = 0.1143462589308945 (0.105218% change)
#     iteration    7: trace = 0.1143104452915286 (0.0313252% change)
#     iteration    8: trace = 0.1143062975706952 (0.00362854% change)
#     iteration    9: trace = 0.1143053640173307 (0.000816715% change)
#     iteration   10: trace = 0.1143051695836231 (0.0001701% change)
#     iteration   11: trace = 0.1143051317698966 (3.30814e-05% change)
#     iteration   12: trace = 0.1143051196009198 (1.0646e-05% change)
#     iteration   13: trace = 0.1143051173861002 (1.93764e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.988, -0.496, 0, 0.988003, 0.217241, 0.259059
# elapsed time for k point: 0.029628753662109375
# Fixing h-field (band 1) phase by -0.308338 + -0.951277i; max ampl. = 1.31283
# Fixing h-field (band 2) phase by -0.400229 + -0.916415i; max ampl. = 2.18443
# total elapsed time for run: 0.05985879898071289
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 4 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.988, -0.4920000000000001, 0.0>
# elapsed time for initialization: 0.021883249282836914
# solve_kpoint (-0.988,-0.492,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 0.9423663272877587 (197.683% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.1527551877369004 (144.205% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1195266744215993 (24.4074% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 63.4629%)
#     iteration    4: trace = 0.1154492830756383 (3.47048% change)
#     iteration    5: trace = 0.1144660580747061 (0.855293% change)
#     iteration    6: trace = 0.1143471023957069 (0.103976% change)
#     iteration    7: trace = 0.1143109284476017 (0.0316402% change)
#     iteration    8: trace = 0.1143065638430076 (0.00381826% change)
#     iteration    9: trace = 0.1143054759764756 (0.000951714% change)
#     iteration   10: trace = 0.1143052402819483 (0.000206197% change)
#     iteration   11: trace = 0.1143051871441759 (4.64876e-05% change)
#     iteration   12: trace = 0.1143051712962576 (1.38646e-05% change)
#     iteration   13: trace = 0.1143051686266101 (2.33554e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.988, -0.492, 0, 0.988003, 0.217241, 0.259059
# elapsed time for k point: 0.03396487236022949
# Fixing h-field (band 1) phase by -0.380755 + -0.924676i; max ampl. = 1.31281
# Fixing h-field (band 2) phase by -0.42898 + -0.903314i; max ampl. = 2.18443
# total elapsed time for run: 0.05854630470275879
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 5 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.98, -0.4920000000000001, 0.0>
# elapsed time for initialization: 0.016730546951293945
# solve_kpoint (-0.98,-0.492,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 0.9417069104123614 (197.685% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.1536194332223575 (143.9% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.119780627573293 (24.7541% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 65.9562%)
#     iteration    4: trace = 0.1155581943172447 (3.58839% change)
#     iteration    5: trace = 0.1145460097512333 (0.879762% change)
#     iteration    6: trace = 0.114422147909996 (0.108191% change)
#     iteration    7: trace = 0.1143852417488384 (0.0322596% change)
#     iteration    8: trace = 0.1143810582530533 (0.00365744% change)
#     iteration    9: trace = 0.1143801448691827 (0.000798548% change)
#     iteration   10: trace = 0.1143799614903005 (0.000160324% change)
#     iteration   11: trace = 0.1143799296672243 (2.78223e-05% change)
#     iteration   12: trace = 0.11437991935444 (9.01625e-06% change)
# Finished solving for bands 1 to 2 after 12 iterations.
# tefreqs:, 1, -0.98, -0.492, 0, 0.980003, 0.21736, 0.259104
# elapsed time for k point: 0.026922941207885742
# Fixing h-field (band 1) phase by -0.312777 + -0.949827i; max ampl. = 1.31284
# Fixing h-field (band 2) phase by -0.398096 + -0.917344i; max ampl. = 2.18396
# total elapsed time for run: 0.04661059379577637
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 6 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.98, -0.4880000000000001, 0.0>
# elapsed time for initialization: 0.02427053451538086
# solve_kpoint (-0.98,-0.488,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 0.9416920006284056 (197.685% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.1531282612198219 (144.054% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.119684266097674 (24.5179% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 58.3213%)
#     iteration    4: trace = 0.1155471455541479 (3.51749% change)
#     iteration    5: trace = 0.1145451838442584 (0.870921% change)
#     iteration    6: trace = 0.1144228708952112 (0.106838% change)
#     iteration    7: trace = 0.1143856895638148 (0.0324999% change)
#     iteration    8: trace = 0.1143813170513735 (0.00382268% change)
#     switching back to exact line minimization
#     iteration    9: trace = 0.1143802669572311 (0.000918069% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 65.3961%)
#     iteration   10: trace = 0.114380045958916 (0.000193214% change)
#     switching back to exact line minimization
#     iteration   11: trace = 0.1143799993472749 (4.07516e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 71.9512%)
#     iteration   12: trace = 0.1143799848716537 (1.26557e-05% change)
#     iteration   13: trace = 0.1143799823115776 (2.23822e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.98, -0.488, 0, 0.980003, 0.217359, 0.259104
# elapsed time for k point: 0.03897666931152344
# Fixing h-field (band 1) phase by -0.385109 + -0.922871i; max ampl. = 1.31283
# Fixing h-field (band 2) phase by -0.42746 + -0.904034i; max ampl. = 2.18397
# total elapsed time for run: 0.08007001876831055
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 7 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.9720000000000001, -0.48800000000000016, 0.0>
# elapsed time for initialization: 0.026723146438598633
# solve_kpoint (-0.972,-0.488,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 0.9409970804932601 (197.686% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.1540799606642312 (143.719% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1199903340591069 (24.8766% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 80.2939%)
#     iteration    4: trace = 0.1156985544101291 (3.6419% change)
#     switching back to exact line minimization
#     iteration    5: trace = 0.1146641253582311 (0.898087% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 50.2532%)
#     iteration    6: trace = 0.1145358273833987 (0.111953% change)
#     switching back to exact line minimization
#     iteration    7: trace = 0.1144975385044002 (0.0334352% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 67.5559%)
#     iteration    8: trace = 0.1144933187483314 (0.00368552% change)
#     iteration    9: trace = 0.1144923564299096 (0.000840505% change)
#     iteration   10: trace = 0.1144921725059609 (0.000160643% change)
#     iteration   11: trace = 0.1144921440088832 (2.489e-05% change)
#     iteration   12: trace = 0.1144921348233026 (8.02289e-06% change)
# Finished solving for bands 1 to 2 after 12 iterations.
# tefreqs:, 1, -0.972, -0.488, 0, 0.972003, 0.217538, 0.259171
# elapsed time for k point: 0.029382944107055664
# Fixing h-field (band 1) phase by -0.317132 + -0.948381i; max ampl. = 1.31289
# Fixing h-field (band 2) phase by -0.396316 + -0.918114i; max ampl. = 2.18333
# total elapsed time for run: 0.059073686599731445
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 8 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.9720000000000001, -0.48400000000000015, 0.0>
# elapsed time for initialization: 0.02706146240234375
# solve_kpoint (-0.972,-0.484,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 0.9410027827772833 (197.686% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.1535910542455159 (143.873% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1198933714144982 (24.6432% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 72.3127%)
#     iteration    4: trace = 0.1156870784556455 (3.571% change)
#     iteration    5: trace = 0.1146629583280725 (0.889186% change)
#     iteration    6: trace = 0.1145364674472542 (0.110376% change)
#     iteration    7: trace = 0.1144979376267042 (0.0336454% change)
#     iteration    8: trace = 0.1144935126198476 (0.00386478% change)
#     iteration    9: trace = 0.1144924789229841 (0.000902847% change)
#     iteration   10: trace = 0.1144922681545767 (0.000184089% change)
#     iteration   11: trace = 0.1144922271391912 (3.58237e-05% change)
#     iteration   12: trace = 0.114492214080565 (1.14057e-05% change)
#     iteration   13: trace = 0.1144922116732766 (2.10258e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.972, -0.484, 0, 0.972003, 0.217537, 0.259171
# elapsed time for k point: 0.027434825897216797
# Fixing h-field (band 1) phase by -0.389484 + -0.921033i; max ampl. = 1.31287
# Fixing h-field (band 2) phase by -0.425955 + -0.904744i; max ampl. = 2.18329
# total elapsed time for run: 0.05657601356506348
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 9 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.964, -0.4840000000000001, 0.0>
# elapsed time for initialization: 0.03618288040161133
# solve_kpoint (-0.964,-0.484,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 0.9402516119888595 (197.688% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.1546319890470276 (143.507% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1202529465371712 (25.0134% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 72.6423%)
#     iteration    4: trace = 0.1158815751332091 (3.70244% change)
#     iteration    5: trace = 0.1148210968517188 (0.919346% change)
#     iteration    6: trace = 0.1146875515443249 (0.116375% change)
#     iteration    7: trace = 0.1146473143289203 (0.0350904% change)
#     iteration    8: trace = 0.1146428998743944 (0.00385054% change)
#     iteration    9: trace = 0.1146419454938072 (0.000832485% change)
#     iteration   10: trace = 0.1146417641893672 (0.000158149% change)
#     iteration   11: trace = 0.1146417376656129 (2.31362e-05% change)
#     iteration   12: trace = 0.1146417294826514 (7.13786e-06% change)
# Finished solving for bands 1 to 2 after 12 iterations.
# tefreqs:, 1, -0.964, -0.484, 0, 0.964003, 0.217775, 0.25926
# elapsed time for k point: 0.02776503562927246
# Fixing h-field (band 1) phase by -0.321525 + -0.946901i; max ampl. = 1.31296
# Fixing h-field (band 2) phase by -0.394574 + -0.918864i; max ampl. = 2.18248
# total elapsed time for run: 0.06867194175720215
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 10 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.964, -0.4800000000000001, 0.0>
# elapsed time for initialization: 0.022834062576293945
# solve_kpoint (-0.964,-0.48,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 0.940282777833875 (197.688% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.1541455176324071 (143.662% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1201551629889182 (24.7833% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 75.3385%)
#     iteration    4: trace = 0.1158694937573356 (3.63154% change)
#     iteration    5: trace = 0.1148194883880491 (0.910321% change)
#     iteration    6: trace = 0.1146878952819178 (0.114674% change)
#     iteration    7: trace = 0.1146476402339771 (0.0351058% change)
#     iteration    8: trace = 0.1146431156639581 (0.00394658% change)
#     iteration    9: trace = 0.1146420762362632 (0.000906668% change)
#     iteration   10: trace = 0.1146418708065362 (0.000179192% change)
#     iteration   11: trace = 0.114641834134649 (3.19882e-05% change)
#     iteration   12: trace = 0.1146418223784534 (1.02547e-05% change)
#     iteration   13: trace = 0.114641820152133 (1.94198e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.964, -0.48, 0, 0.964003, 0.217774, 0.259261
# elapsed time for k point: 0.023620128631591797
# Fixing h-field (band 1) phase by -0.393926 + -0.919142i; max ampl. = 1.31294
# Fixing h-field (band 2) phase by -0.424467 + -0.905443i; max ampl. = 2.18238
# total elapsed time for run: 0.048658132553100586
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 11 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.956, -0.4800000000000001, 0.0>
# elapsed time for initialization: 0.03274083137512207
# solve_kpoint (-0.956,-0.48,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 0.9394537217828957 (197.69% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.1552774230379489 (143.264% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1205697904727934 (25.1644% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 68.9021%)
#     iteration    4: trace = 0.1161077466619274 (3.77057% change)
#     switching back to exact line minimization
#     iteration    5: trace = 0.1150170595749157 (0.943808% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 66.6404%)
#     iteration    6: trace = 0.1148769818504513 (0.121863% change)
#     iteration    7: trace = 0.1148345284465206 (0.0369624% change)
#     iteration    8: trace = 0.1148299579672995 (0.00398014% change)
#     iteration    9: trace = 0.1148288905510521 (0.000929567% change)
#     iteration   10: trace = 0.1148286918659701 (0.000173027% change)
#     iteration   11: trace = 0.1148286632107607 (2.49548e-05% change)
#     iteration   12: trace = 0.1148286542785807 (7.7787e-06% change)
# Finished solving for bands 1 to 2 after 12 iterations.
# tefreqs:, 1, -0.956, -0.48, 0, 0.956003, 0.218071, 0.259372
# elapsed time for k point: 0.032144784927368164
# Fixing h-field (band 1) phase by -0.32596 + -0.945383i; max ampl. = 1.31304
# Fixing h-field (band 2) phase by -0.392875 + -0.919592i; max ampl. = 2.18139
# total elapsed time for run: 0.06695723533630371
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 12 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.956, -0.4760000000000001, 0.0>
# elapsed time for initialization: 0.023836374282836914
# solve_kpoint (-0.956,-0.476,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.5132892042661845 (198.678% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 0.1403754835435873 (114.099% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1183815802240102 (16.9997% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 65.0452%)
#     iteration    4: trace = 0.1156650056990786 (2.3214% change)
#     iteration    5: trace = 0.1149652008865765 (0.606863% change)
#     iteration    6: trace = 0.1148717616849027 (0.0813091% change)
#     iteration    7: trace = 0.114835438135599 (0.031626% change)
#     iteration    8: trace = 0.1148312610890611 (0.00363749% change)
#     iteration    9: trace = 0.1148292157713246 (0.00178117% change)
#     iteration   10: trace = 0.1148288534380987 (0.000315541% change)
#     iteration   11: trace = 0.1148287784128012 (6.53366e-05% change)
#     iteration   12: trace = 0.114828760737153 (1.5393e-05% change)
#     iteration   13: trace = 0.1148287582152802 (2.1962e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.956, -0.476, 0, 0.956003, 0.21807, 0.259373
# elapsed time for k point: 0.0245513916015625
# Fixing h-field (band 1) phase by 0.647247 + -0.76228i; max ampl. = 1.31308
# Fixing h-field (band 2) phase by -0.797423 + -0.60342i; max ampl. = 2.18128
# total elapsed time for run: 0.05073904991149902
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 13 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.948, -0.4760000000000001, 0.0>
# elapsed time for initialization: 0.024471759796142578
# solve_kpoint (-0.948,-0.476,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.5106555423172685 (198.685% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.1405029501692055 (113.69% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1185765137877978 (16.9264% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 73.6373%)
#     iteration    4: trace = 0.1158789332667645 (2.30115% change)
#     iteration    5: trace = 0.1151856684429669 (0.600061% change)
#     iteration    6: trace = 0.1150943867791878 (0.0792788% change)
#     iteration    7: trace = 0.1150592499218189 (0.0305334% change)
#     iteration    8: trace = 0.1150552632937122 (0.00346491% change)
#     iteration    9: trace = 0.115053300733644 (0.00170577% change)
#     iteration   10: trace = 0.1150529411629423 (0.000312526% change)
#     iteration   11: trace = 0.1150528650329916 (6.61695e-05% change)
#     iteration   12: trace = 0.1150528469090551 (1.57527e-05% change)
#     iteration   13: trace = 0.1150528442979832 (2.26945e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.948, -0.476, 0, 0.948003, 0.218426, 0.259505
# elapsed time for k point: 0.021887540817260742
# Fixing h-field (band 1) phase by 0.650802 + -0.759247i; max ampl. = 1.31321
# Fixing h-field (band 2) phase by -0.799646 + -0.600472i; max ampl. = 2.17986
# total elapsed time for run: 0.04840564727783203
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 14 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.948, -0.4720000000000001, 0.0>
# elapsed time for initialization: 0.02071094512939453
# solve_kpoint (-0.948,-0.472,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.5146226264478433 (198.675% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 0.1407052349223508 (114.116% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.118617627122114 (17.0348% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 73.1013%)
#     iteration    4: trace = 0.1158942036455749 (2.32263% change)
#     iteration    5: trace = 0.115190858634797 (0.608733% change)
#     iteration    6: trace = 0.1150966241929877 (0.0818407% change)
#     iteration    7: trace = 0.1150598164743953 (0.031985% change)
#     iteration    8: trace = 0.1150555455948989 (0.00371195% change)
#     iteration    9: trace = 0.1150534366766881 (0.00183297% change)
#     iteration   10: trace = 0.1150530626030398 (0.000325131% change)
#     iteration   11: trace = 0.1150529845003082 (6.78841e-05% change)
#     iteration   12: trace = 0.1150529660536766 (1.60332e-05% change)
#     iteration   13: trace = 0.1150529633955894 (2.31032e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.948, -0.472, 0, 0.948003, 0.218425, 0.259507
# elapsed time for k point: 0.019598007202148438
# Fixing h-field (band 1) phase by 0.641697 + -0.766959i; max ampl. = 1.31319
# Fixing h-field (band 2) phase by -0.800774 + -0.598966i; max ampl. = 2.17985
# total elapsed time for run: 0.042720794677734375
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 15 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.94, -0.4720000000000001, 0.0>
# elapsed time for initialization: 0.03664565086364746
# solve_kpoint (-0.94,-0.472,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.5121202578363977 (198.681% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.140883889561686 (113.701% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.118854549064982 (16.9627% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 70.2959%)
#     iteration    4: trace = 0.1161475509767044 (2.30381% change)
#     iteration    5: trace = 0.1154493446538823 (0.60295% change)
#     iteration    6: trace = 0.1153567805403789 (0.0802094% change)
#     iteration    7: trace = 0.1153208828490677 (0.0311237% change)
#     iteration    8: trace = 0.1153167564305524 (0.00357827% change)
#     iteration    9: trace = 0.1153147024496996 (0.00178118% change)
#     iteration   10: trace = 0.1153143276452111 (0.000325028% change)
#     iteration   11: trace = 0.1153142476229442 (6.93949e-05% change)
#     iteration   12: trace = 0.1153142285334493 (1.65543e-05% change)
#     iteration   13: trace = 0.11531422575034 (2.4135e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.94, -0.472, 0, 0.940003, 0.218839, 0.259661
# elapsed time for k point: 0.02696990966796875
# Fixing h-field (band 1) phase by 0.645007 + -0.764176i; max ampl. = 1.31334
# Fixing h-field (band 2) phase by -0.803004 + -0.595974i; max ampl. = 2.17815
# total elapsed time for run: 0.06660890579223633
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 16 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.94, -0.4680000000000001, 0.0>
# elapsed time for initialization: 0.025817394256591797
# solve_kpoint (-0.94,-0.468,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.5161033401538906 (198.671% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 0.1410890680833389 (114.126% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1188955847914901 (17.0729% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 79.014%)
#     iteration    4: trace = 0.1161628435819959 (2.32516% change)
#     iteration    5: trace = 0.1154545802830305 (0.61158% change)
#     iteration    6: trace = 0.1153590528836522 (0.0827745% change)
#     iteration    7: trace = 0.1153214701568543 (0.0325842% change)
#     iteration    8: trace = 0.1153170549056643 (0.00382872% change)
#     iteration    9: trace = 0.1153148522681063 (0.00191009% change)
#     iteration   10: trace = 0.1153144627264975 (0.000337808% change)
#     iteration   11: trace = 0.1153143806700525 (7.11589e-05% change)
#     iteration   12: trace = 0.1153143612411716 (1.68486e-05% change)
#     iteration   13: trace = 0.1153143584074515 (2.45739e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.94, -0.468, 0, 0.940003, 0.218837, 0.259662
# elapsed time for k point: 0.025222301483154297
# Fixing h-field (band 1) phase by 0.636033 + -0.771662i; max ampl. = 1.31332
# Fixing h-field (band 2) phase by -0.804145 + -0.594433i; max ampl. = 2.17815
# total elapsed time for run: 0.05405879020690918
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 17 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.9319999999999999, -0.4680000000000001, 0.0>
# elapsed time for initialization: 0.030843257904052734
# solve_kpoint (-0.932,-0.468,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.5137324973043063 (198.677% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.1413186638041721 (113.705% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1191745074911048 (17.0017% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 81.1808%)
#     iteration    4: trace = 0.1164556022764903 (2.30777% change)
#     iteration    5: trace = 0.1157510371203617 (0.606843% change)
#     iteration    6: trace = 0.115656671422096 (0.081558% change)
#     iteration    7: trace = 0.1156197064620075 (0.031966% change)
#     iteration    8: trace = 0.1156153857638995 (0.00373706% change)
#     iteration    9: trace = 0.1156132071666141 (0.00188437% change)
#     iteration   10: trace = 0.1156128129574329 (0.000340973% change)
#     iteration   11: trace = 0.1156127280181732 (7.34688e-05% change)
#     iteration   12: trace = 0.1156127077125007 (1.75635e-05% change)
#     iteration   13: trace = 0.1156127047095831 (2.59739e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.932, -0.468, 0, 0.932003, 0.21931, 0.259838
# elapsed time for k point: 0.02400493621826172
# Fixing h-field (band 1) phase by 0.639079 + -0.769141i; max ampl. = 1.3135
# Fixing h-field (band 2) phase by -0.806384 + -0.591393i; max ampl. = 2.17616
# total elapsed time for run: 0.05759596824645996
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 18 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.9319999999999999, -0.4640000000000001, 0.0>
# elapsed time for initialization: 0.024991989135742188
# solve_kpoint (-0.932,-0.464,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.5177301954323805 (198.667% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 0.1415267339521258 (114.13% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1192154357688374 (17.1137% change)
#     linmin: converged after 3 iterations.
# ...
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.988, 0.4920000000000001, 0.0>
# elapsed time for initialization: 0.02410292625427246
# solve_kpoint (0.988,0.492,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.7188071477589061 (198.243% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.148614950943011 (131.468% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1196673867169843 (21.5799% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 61.7182%)
#     iteration    4: trace = 0.1156503223190607 (3.41416% change)
#     iteration    5: trace = 0.11451689270045 (0.984875% change)
#     iteration    6: trace = 0.1143748608416913 (0.124104% change)
#     iteration    7: trace = 0.114325610423187 (0.0430698% change)
#     iteration    8: trace = 0.1143200624270274 (0.00485292% change)
#     iteration    9: trace = 0.1143183142254382 (0.00152923% change)
#     iteration   10: trace = 0.114317872570762 (0.000386338% change)
#     iteration   11: trace = 0.1143177835578414 (7.78644e-05% change)
#     iteration   12: trace = 0.1143177551855972 (2.48188e-05% change)
#     iteration   13: trace = 0.1143177506279889 (3.98679e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, 0.988, 0.492, 0, 0.988003, 0.21725, 0.259075
# elapsed time for k point: 0.02666926383972168
# Fixing h-field (band 1) phase by -0.453804 + -0.891101i; max ampl. = 1.31334
# Fixing h-field (band 2) phase by -0.226991 + 0.973897i; max ampl. = 2.1847
# total elapsed time for run: 0.054932594299316406
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 498 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.988, 0.4960000000000001, 0.0>
# elapsed time for initialization: 0.022060394287109375
# solve_kpoint (0.988,0.496,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.7206017916220683 (198.239% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.1489596095631525 (131.478% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1197681276600982 (21.7257% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 67.0219%)
#     iteration    4: trace = 0.1156806136090641 (3.47211% change)
#     iteration    5: trace = 0.1145260613657423 (1.00306% change)
#     iteration    6: trace = 0.1143783723236268 (0.12904% change)
#     iteration    7: trace = 0.114326383167302 (0.045464% change)
#     iteration    8: trace = 0.1143203625590875 (0.0052663% change)
#     iteration    9: trace = 0.1143183524209151 (0.00175835% change)
#     iteration   10: trace = 0.1143178560059366 (0.00043424% change)
#     iteration   11: trace = 0.1143177564457114 (8.70907e-05% change)
#     iteration   12: trace = 0.1143177258572448 (2.67574e-05% change)
#     iteration   13: trace = 0.114317721106881 (4.1554e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, 0.988, 0.496, 0, 0.988003, 0.217251, 0.259075
# elapsed time for k point: 0.02561664581298828
# Fixing h-field (band 1) phase by -0.447975 + -0.894046i; max ampl. = 1.31344
# Fixing h-field (band 2) phase by -0.319877 + 0.947459i; max ampl. = 2.18468
# total elapsed time for run: 0.04944276809692383
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 499 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.996, 0.4960000000000001, 0.0>
# elapsed time for initialization: 0.018448352813720703
# solve_kpoint (0.996,0.496,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.7208516558824748 (198.238% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.1485138584491919 (131.668% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1195575843885318 (21.6034% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 0.1155893559964306 (3.37511% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 52.7051%)
#     iteration    5: trace = 0.1144521373167297 (0.988707% change)
#     iteration    6: trace = 0.1143282425117285 (0.108309% change)
#     iteration    7: trace = 0.114288326457935 (0.0349197% change)
#     iteration    8: trace = 0.114282134065419 (0.00541837% change)
#     iteration    9: trace = 0.1142807852902955 (0.00118022% change)
#     iteration   10: trace = 0.1142803370648836 (0.000392215% change)
#     iteration   11: trace = 0.1142802568997744 (7.01478e-05% change)
#     iteration   12: trace = 0.1142802319207786 (2.18577e-05% change)
#     iteration   13: trace = 0.1142802275010576 (3.86744e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, 0.996, 0.496, 0, 0.996003, 0.217191, 0.259053
# elapsed time for k point: 0.04184079170227051
# Fixing h-field (band 1) phase by -0.453228 + -0.891395i; max ampl. = 1.31335
# Fixing h-field (band 2) phase by -0.232537 + 0.972588i; max ampl. = 2.18496
# total elapsed time for run: 0.06264734268188477
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 500 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.996, 0.5000000000000001, 0.0>
# elapsed time for initialization: 0.031203269958496094
# solve_kpoint (0.996,0.5,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.7227277010922508 (198.234% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.1488675552519962 (131.68% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1196569834586481 (21.7564% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 72.206%)
#     iteration    4: trace = 0.1156182868254933 (3.43317% change)
#     iteration    5: trace = 0.1144824603982268 (0.987243% change)
#     iteration    6: trace = 0.1143387995251927 (0.125566% change)
#     iteration    7: trace = 0.11428858259592 (0.0439291% change)
#     iteration    8: trace = 0.1142827308559418 (0.00512028% change)
#     iteration    9: trace = 0.1142808191185367 (0.00167283% change)
#     iteration   10: trace = 0.1142803420768686 (0.00041743% change)
#     iteration   11: trace = 0.1142802464763696 (8.36544e-05% change)
#     iteration   12: trace = 0.1142802169887441 (2.58029e-05% change)
#     iteration   13: trace = 0.1142802123699172 (4.04167e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, 0.996, 0.5, 0, 0.996003, 0.217191, 0.259053
# elapsed time for k point: 0.02282094955444336
# Fixing h-field (band 1) phase by -0.447327 + -0.894371i; max ampl. = 1.31344
# Fixing h-field (band 2) phase by -0.323782 + 0.946132i; max ampl. = 2.18491
# total elapsed time for run: 0.05658984184265137
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 501 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<1.004, 0.5000000000000001, 0.0>
# elapsed time for initialization: 0.019672393798828125
# solve_kpoint (1.004,0.5,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.7229337417795546 (198.233% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.1484926310570742 (131.839% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1194976095933624 (21.6389% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 76.9088%)
#     iteration    4: trace = 0.1155699618612643 (3.34172% change)
#     iteration    5: trace = 0.1144695047084326 (0.956755% change)
#     iteration    6: trace = 0.114334090643574 (0.118367% change)
#     iteration    7: trace = 0.1142876335283539 (0.040641% change)
#     iteration    8: trace = 0.1142823083580886 (0.00465955% change)
#     iteration    9: trace = 0.1142806906451588 (0.00141555% change)
#     iteration   10: trace = 0.1142802761932959 (0.000362662% change)
#     iteration   11: trace = 0.1142801929197796 (7.28678e-05% change)
#     iteration   12: trace = 0.1142801662538395 (2.33338e-05% change)
#     iteration   13: trace = 0.1142801618950561 (3.81412e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, 1.004, 0.5, 0, 1.004, 0.217191, 0.259053
# elapsed time for k point: 0.027604341506958008
# Fixing h-field (band 1) phase by -0.452498 + -0.891766i; max ampl. = 1.31335
# Fixing h-field (band 2) phase by -0.238747 + 0.971082i; max ampl. = 2.18494
# total elapsed time for run: 0.04974198341369629
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Calculating 502 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 2 and 6 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<1.004, 0.5040000000000001, 0.0>
# elapsed time for initialization: 0.039360761642456055
# solve_kpoint (1.004,0.504,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.7248870142405603 (198.229% change)
#     linmin: converged after 9 iterations.
#     iteration    2: trace = 0.1488555773898933 (131.854% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.1195958322115972 (21.7989% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 0.1155976639409756 (3.3999% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 60.8324%)
#     iteration    5: trace = 0.1144552587310554 (0.993167% change)
#     iteration    6: trace = 0.1143294727980085 (0.10996% change)
#     iteration    7: trace = 0.1142887353555726 (0.035638% change)
#     iteration    8: trace = 0.1142822225877408 (0.00569868% change)
#     iteration    9: trace = 0.1142807635146909 (0.00127674% change)
#     iteration   10: trace = 0.1142802767815365 (0.000425911% change)
#     iteration   11: trace = 0.1142801914004611 (7.4712e-05% change)
#     iteration   12: trace = 0.1142801655065719 (2.26583e-05% change)
#     iteration   13: trace = 0.1142801610134807 (3.93165e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, 1.004, 0.504, 0, 1.004, 0.217191, 0.259053
# elapsed time for k point: 0.02456498146057129
# Fixing h-field (band 1) phase by -0.446195 + -0.894936i; max ampl. = 1.31347
# Fixing h-field (band 2) phase by -0.327448 + 0.944869i; max ampl. = 2.18495
# total elapsed time for run: 0.06609845161437988
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 7.59022, harm. mean 2.39755, 66.1133% > 1, 59.9111% "fill"
# Elapsed: 36.108582735061646

# %%
fig,ax=plt.subplots(1,2,figsize=(15,5))
ax[0].plot(fields_cur[:, 0]*(2*np.pi)**2)
ax[0].set_ylabel('berry curvature for band1')
ax[1].plot(fields_cur[:, 1]*(2*np.pi)**2)
ax[1].set_ylabel('berry curvature for band2')
# Out:
# Text(0, 0.5, 'berry curvature for band2')

# %%
fig,ax=plt.subplots(1,2,figsize=(15,5))
ax[0].plot(np.real(neiji[:, 0]))
ax[0].set_ylabel('real neiji band1')
ax[1].plot(np.imag(neiji[:, 0]))
ax[1].set_ylabel('imaginary neiji band1')
# Out:
# Text(0, 0.5, 'imaginary neiji band1')

# %%
print((neiji[:,1]))
b=np.log(neiji[:,1])
print(b)
a=-np.imag(b[7])/(deltakxg**2*np.sqrt(3))
print(a)
print(a*(6.28**2))
a=-np.imag(b[41])/(deltakxg**2*np.sqrt(3))
print(a)
print(a*(6.28**2))
# Out:
# [ 1.   -0.j     1.   -0.j     1.   -0.j     1.   -0.j     1.   -0.j
#   1.   -0.j     1.   +0.j    -1.   -0.008j  1.   -0.003j  1.   +0.001j
#   1.   +0.007j -1.   +0.008j  1.   -0.j     1.   -0.j     1.   +0.j
#   1.   +0.j     1.   +0.j     1.   +0.j     1.   -0.j     1.   +0.j
#   1.   -0.j     1.   -0.j     1.   -0.j     1.   -0.j     1.   -0.j
#   1.   +0.j     1.   +0.j     1.   +0.j     1.   -0.j     1.   -0.j
#   1.   +0.j     1.   -0.j     1.   -0.j     1.   -0.j     1.   -0.j
#   1.   +0.j     1.   -0.001j -0.999-0.05j   0.999-0.045j  1.   -0.j
#   1.   +0.003j -1.   +0.009j  1.   -0.j     1.   +0.j     1.   +0.j
#   1.   +0.j     1.   +0.j     1.   -0.j     1.   +0.j     1.   -0.j   ]
# [-0.-0.j    -0.-0.j     0.-0.j    -0.-0.j     0.-0.j     0.-0.j
#  -0.+0.j    -0.-3.133j  0.-0.003j -0.+0.001j  0.+0.007j  0.+3.134j
#  -0.-0.j     0.-0.j     0.+0.j    -0.+0.j     0.+0.j     0.+0.j
#  -0.-0.j    -0.+0.j    -0.-0.j    -0.-0.j    -0.-0.j     0.-0.j
#   0.-0.j     0.+0.j     0.+0.j     0.+0.j     0.-0.j     0.-0.j
#  -0.+0.j     0.-0.j     0.-0.j    -0.-0.j    -0.-0.j    -0.+0.j
#   0.-0.001j -0.-3.091j -0.-0.045j -0.-0.j     0.+0.003j  0.+3.133j
#   0.-0.j     0.+0.j     0.+0.j    -0.+0.j    -0.+0.j    -0.-0.j
#   0.+0.j    -0.-0.j   ]
# 85.92251850546418
# 3388.6466538258987
# -85.90650366985545
# -3388.0150543332275

# %%
print((neiji[:,1]))
b=np.log(neiji[:,1])
print(b)
a=-np.imag(b[41])/(deltakxg**2*np.sqrt(3))
print(a)
print(a*(6.28**2))
a=-np.imag(b[57])/(deltakxg**2*np.sqrt(3))
print(a)
print(a*(6.28**2))
a=-np.imag(b[191])/(deltakxg**2*np.sqrt(3))
print(a)
print(a*(6.28**2))
a=-np.imag(b[207])/(deltakxg**2*np.sqrt(3))
print(a)
print(a*(6.28**2))
# Out:
# [ 1.   +0.j     1.   +0.j     1.   -0.j     1.   -0.j     1.   -0.j
#   1.   -0.j     1.   -0.j     1.   -0.j     1.   -0.j     1.   -0.j
#   1.   -0.j     1.   -0.j     1.   -0.j     1.   -0.j     1.   -0.j
#   1.   -0.j     1.   -0.j     1.   -0.j     1.   -0.j     1.   -0.j
#   1.   +0.j     1.   +0.j     1.   -0.j     1.   -0.j     1.   -0.j
#   1.   -0.j     1.   -0.j     1.   +0.j     1.   +0.j     1.   +0.j
#   1.   -0.j     1.   -0.j     1.   +0.j     1.   +0.j     1.   +0.j
#   1.   +0.j     1.   +0.j     1.   -0.j     1.   -0.j     1.   -0.j
#   1.   -0.008j -0.999-0.032j  1.   -0.001j  1.   -0.j     1.   -0.j
#   1.   +0.j     1.   -0.j     1.   +0.j     1.   -0.j     1.   -0.j
#   1.   +0.j     1.   -0.j     1.   +0.j     1.   +0.j     1.   -0.002j
#   1.   -0.002j  1.   +0.011j -1.   +0.009j  1.   +0.j     1.   +0.001j
#   1.   +0.j     1.   +0.j     1.   +0.j     1.   -0.j     1.   -0.j
#   1.   -0.j     1.   +0.j     1.   +0.j     1.   -0.j     1.   -0.j
#   1.   -0.j     1.   -0.j     1.   +0.j     1.   -0.j     1.   -0.j
#   1.   +0.j     1.   +0.j     1.   -0.j     1.   +0.j     1.   -0.j
#   1.   +0.j     1.   +0.j     1.   +0.j     1.   -0.j     1.   -0.j
#   1.   +0.j     1.   -0.j     1.   +0.j     1.   +0.j     1.   +0.j
#   1.   +0.j     1.   +0.j     1.   +0.j     1.   -0.j     1.   +0.j
#   1.   -0.j     1.   -0.j     1.   +0.j     1.   +0.j     1.   -0.j
#   1.   +0.j     1.   +0.j     1.   +0.j     1.   +0.j     1.   +0.j
#   1.   +0.j     1.   +0.j     1.   +0.j     1.   +0.j     1.   -0.j
#   1.   +0.j     1.   -0.j     1.   +0.j     1.   +0.j     1.   -0.j
#   1.   +0.j     1.   +0.j     1.   +0.j     1.   +0.j     1.   -0.j
#   1.   -0.j     1.   +0.j     1.   -0.j     1.   -0.j     1.   +0.j
#   1.   -0.j     1.   -0.j     1.   -0.j     1.   -0.j     1.   -0.j
#   1.   +0.j     1.   +0.j     1.   -0.j     1.   +0.j     1.   -0.j
#   1.   +0.j     1.   -0.j     1.   +0.j     1.   -0.j     1.   -0.j
#   1.   +0.j     1.   +0.j     1.   -0.j     1.   +0.j     1.   +0.j
#   1.   +0.j     1.   +0.j     1.   -0.j     1.   -0.j     1.   -0.j
#   1.   +0.j     1.   +0.j     1.   -0.j     1.   +0.j     1.   -0.j
#   1.   +0.j     1.   +0.j     1.   -0.j     1.   +0.j     1.   +0.j
#   1.   +0.j     1.   +0.j     1.   -0.j     1.   -0.j     1.   -0.j
#   1.   -0.j     1.   +0.j     1.   +0.j     1.   -0.j     1.   +0.j
#   1.   -0.j     1.   +0.j     1.   +0.j     1.   +0.j     1.   +0.j
#   1.   +0.j     1.   -0.j     1.   -0.j     1.   -0.j     1.   -0.j
#   1.   +0.j     1.   -0.j     1.   +0.j     1.   +0.j     1.   -0.j
#   1.   +0.j     1.   -0.j     1.   -0.j     1.   +0.j     1.   -0.002j
#   1.   -0.001j -1.   -0.007j  1.   +0.j     1.   +0.j     1.   -0.j
#   1.   +0.001j  1.   -0.j     1.   -0.j     1.   +0.j     1.   -0.j
#   1.   +0.j     1.   +0.j     1.   +0.j     1.   +0.j     1.   -0.j
#   1.   +0.j     1.   +0.001j -0.999+0.036j  1.   +0.009j  1.   +0.j
#   1.   +0.j     1.   +0.j     1.   +0.j     1.   +0.j     1.   +0.j
#   1.   -0.j     1.   -0.j     1.   -0.j     1.   +0.j     1.   +0.j
#   1.   +0.j     1.   +0.j     1.   +0.j     1.   +0.j     1.   -0.j
#   1.   -0.j     1.   +0.j     1.   -0.j     1.   -0.j     1.   +0.j
#   1.   +0.j     1.   +0.j     1.   +0.j     1.   +0.j     1.   +0.j
#   1.   +0.j     1.   +0.j     1.   +0.j     1.   +0.j     1.   -0.j
#   1.   +0.j     1.   -0.j     1.   -0.j     1.   -0.j     1.   -0.j
#   1.   +0.j     1.   +0.j     1.   -0.j     1.   -0.j     1.   -0.j   ]
# [-0.+0.j    -0.+0.j     0.-0.j    -0.-0.j    -0.-0.j    -0.-0.j
#   0.-0.j     0.-0.j    -0.-0.j    -0.-0.j     0.-0.j    -0.-0.j
#  -0.-0.j    -0.-0.j    -0.-0.j     0.-0.j     0.-0.j     0.-0.j
#  -0.-0.j    -0.-0.j    -0.+0.j     0.+0.j     0.-0.j     0.-0.j
#   0.-0.j    -0.-0.j    -0.-0.j    -0.+0.j     0.+0.j    -0.+0.j
#  -0.-0.j    -0.-0.j    -0.+0.j    -0.+0.j     0.+0.j    -0.+0.j
#  -0.+0.j     0.-0.j     0.-0.j     0.-0.j     0.-0.008j -0.-3.109j
#  -0.-0.001j  0.-0.j     0.-0.j    -0.+0.j     0.-0.j     0.+0.j
#   0.-0.j    -0.-0.j     0.+0.j     0.-0.j    -0.+0.j    -0.+0.j
#   0.-0.002j  0.-0.002j  0.+0.011j  0.+3.133j -0.+0.j     0.+0.001j
#   0.+0.j     0.+0.j    -0.+0.j     0.-0.j    -0.-0.j     0.-0.j
#   0.+0.j     0.+0.j     0.-0.j    -0.-0.j    -0.-0.j     0.-0.j
#   0.+0.j     0.-0.j     0.-0.j     0.+0.j    -0.+0.j    -0.-0.j
#  -0.+0.j    -0.-0.j     0.+0.j    -0.+0.j    -0.+0.j     0.-0.j
#  -0.-0.j     0.+0.j     0.-0.j     0.+0.j     0.+0.j    -0.+0.j
#  -0.+0.j    -0.+0.j    -0.+0.j     0.-0.j     0.+0.j     0.-0.j
#   0.-0.j     0.+0.j     0.+0.j    -0.-0.j     0.+0.j     0.+0.j
#  -0.+0.j    -0.+0.j     0.+0.j    -0.+0.j    -0.+0.j    -0.+0.j
#   0.+0.j     0.-0.j    -0.+0.j     0.-0.j    -0.+0.j     0.+0.j
#   0.-0.j    -0.+0.j    -0.+0.j    -0.+0.j    -0.+0.j     0.-0.j
#   0.-0.j    -0.+0.j     0.-0.j     0.-0.j    -0.+0.j    -0.-0.j
#   0.-0.j     0.-0.j     0.-0.j     0.-0.j     0.+0.j     0.+0.j
#  -0.-0.j    -0.+0.j    -0.-0.j    -0.+0.j    -0.-0.j    -0.+0.j
#   0.-0.j     0.-0.j    -0.+0.j    -0.+0.j     0.-0.j    -0.+0.j
#  -0.+0.j    -0.+0.j     0.+0.j    -0.-0.j     0.-0.j    -0.-0.j
#   0.+0.j     0.+0.j    -0.-0.j    -0.+0.j    -0.-0.j     0.+0.j
#  -0.+0.j    -0.-0.j     0.+0.j     0.+0.j     0.+0.j     0.+0.j
#   0.-0.j     0.-0.j     0.-0.j     0.-0.j     0.+0.j    -0.+0.j
#   0.-0.j    -0.+0.j    -0.-0.j     0.+0.j     0.+0.j    -0.+0.j
#  -0.+0.j     0.+0.j    -0.-0.j     0.-0.j     0.-0.j     0.-0.j
#   0.+0.j     0.-0.j    -0.+0.j    -0.+0.j    -0.-0.j    -0.+0.j
#  -0.-0.j    -0.-0.j    -0.+0.j     0.-0.002j -0.-0.001j -0.-3.135j
#  -0.+0.j     0.+0.j    -0.-0.j     0.+0.001j -0.-0.j    -0.-0.j
#   0.+0.j     0.-0.j    -0.+0.j    -0.+0.j     0.+0.j     0.+0.j
#  -0.-0.j    -0.+0.j     0.+0.001j  0.+3.106j -0.+0.009j -0.+0.j
#   0.+0.j     0.+0.j    -0.+0.j    -0.+0.j    -0.+0.j     0.-0.j
#  -0.-0.j    -0.-0.j     0.+0.j     0.+0.j     0.+0.j     0.+0.j
#   0.+0.j     0.+0.j    -0.-0.j    -0.-0.j    -0.+0.j    -0.-0.j
#  -0.-0.j    -0.+0.j    -0.+0.j    -0.+0.j    -0.+0.j    -0.+0.j
#  -0.+0.j     0.+0.j    -0.+0.j    -0.+0.j     0.+0.j     0.-0.j
#   0.+0.j     0.-0.j     0.-0.j     0.-0.j     0.-0.j    -0.+0.j
#  -0.+0.j    -0.-0.j     0.-0.j    -0.-0.j   ]
# 2131.396991960524
# 84058.88712773593
# -2147.6383492855725
# -84699.42027446412
# 2148.9842117937587
# 84752.49893840698
# -2129.102640206526
# -83968.40156552105

# %%
fig,ax=plt.subplots(1,2,figsize=(15,5))
ax[0].plot(np.real(neiji[:,1]))
ax[0].set_ylabel('real neiji band2')
ax[1].plot(np.imag(neiji[:, 1]))
ax[1].set_ylabel('imaginary neiji band2')
# Out:
# Text(0, 0.5, 'imaginary neiji band2')

# %%
fig,ax=plt.subplots(1,2,figsize=(15,5))
ax[0].plot(np.real(neiji[:,1]))
ax[0].set_ylabel('real neiji band2')
ax[1].plot(np.imag(neiji[:, 1]))
ax[1].set_ylabel('imaginary neiji band2')
# Out:
# Text(0, 0.5, 'imaginary neiji band2')

# %%
# calculate the curveture
if do_chern:
    time_s = time.time()
    fields_cur = np.zeros((Nkxg, N_max))
    neiji = np.zeros((Nkxg, N_max), dtype=complex)
    fields = []
    rr1 = 181/385/2
    rr2 = 81/385/2
    eps_si = 12
    #fields_cur = np.zeros((Nkxg, N_max))
    for m in range(Nkxg+1):
        for n in range(Nkyg+1): #平均伟Nkyg,实际边界有Nkyg+1个点
            print('Calculating', m * (Nkyg+1) + n + 1, 'of', (Nkxg/2+1) * (Nkyg+1), '...')
            omega, f, field_temp, eps_arr, eps = eigs_PCs(Pxg, Pyg,
                                                          # valley photonic crystal K Path
                                                    # left part1 from negative
                                                  (m  - Nkxg/2 +0.5) * deltakxg * np.sqrt(3), # 扫描平行四边形Kx
                                                  (n - 0.5 ) * deltakyg, # 扫描Ky，要键入kx的1/2
                                                  N_max, 0, Polarflag, rr1, rr2, eps_si)
            fields.append(field_temp)

    

    for m in range(Nkxg):
        for n in range(Nkyg):#这里不能是Nkyg+1，因为最右侧和最底部的边不能包括进来画网格
            field1 = fields[m*(Nkyg+1)+n] #将平行四边形分割成若干小网格，每个网格的四个顶点,=把field又排列一遍
            field4 = fields[m*(Nkyg+1)+n+1]
            field3 = fields[(m+1)*(Nkyg+1)+n+1]
            field2 = fields[(m+1)*(Nkyg+1)+n]

            for mm in range(N_max): #对每一个能带计算陈数
                temp = field1[:, mm].conj().T * eps_arr @ field2[:, mm] #一行乘以一列变成一个数
                fieldtemp[mm] = temp / np.abs(temp)
                temp = field2[:, mm].conj().T * eps_arr @ field3[:, mm]
                fieldtemp[mm] *= temp / np.abs(temp) #这里是把前面的值再乘新值
                temp = field3[:, mm].conj().T * eps_arr @ field4[:, mm]
                fieldtemp[mm] *= temp / np.abs(temp)
                temp = field4[:, mm].conj().T * eps_arr @ field1[:, mm]
                fieldtemp[mm] *= temp / np.abs(temp)
                neiji [m, mm] = fieldtemp[mm]
                fields_cur[m, mm] = -np.imag(np.log(fieldtemp[mm]))/(deltakxg**2*np.sqrt(3))
            

 
    print('Elapsed:', time.time() - time_s)
    
    plt.plot(fields_cur[:, 0]*(2*np.pi)**2)
    plt.show()
# Out:
# Calculating 1 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.996, -0.5000000000000001, 0.0>
# elapsed time for initialization: 0.026751995086669922
# solve_kpoint (-0.996,-0.5,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2453434653694976 (199.002% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1024201488152094 (82.1957% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.08873803404564817 (14.315% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 82.5993%)
#     iteration    4: trace = 0.08662718550086901 (2.40737% change)
#     iteration    5: trace = 0.08610413121210012 (0.605628% change)
#     iteration    6: trace = 0.0860353471451898 (0.0799167% change)
#     iteration    7: trace = 0.08601733735873024 (0.0209352% change)
#     iteration    8: trace = 0.08601548832943801 (0.00214962% change)
#     iteration    9: trace = 0.08601486275537812 (0.000727283% change)
#     iteration   10: trace = 0.08601471187675321 (0.00017541% change)
#     iteration   11: trace = 0.08601468585440364 (3.02534e-05% change)
#     iteration   12: trace = 0.0860146776922705 (9.48923e-06% change)
# Finished solving for bands 1 to 2 after 12 iterations.
# tefreqs:, 1, -0.996, -0.5, 0, 0.996003, 0.182308, 0.229736
# elapsed time for k point: 0.03830265998840332
# Fixing h-field (band 1) phase by -0.654032 + -0.756467i; max ampl. = 1.46197
# Fixing h-field (band 2) phase by 0.773697 + -0.633555i; max ampl. = 1.68908
# total elapsed time for run: 0.06776785850524902
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 2 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.996, -0.4960000000000001, 0.0>
# elapsed time for initialization: 0.02844548225402832
# solve_kpoint (-0.996,-0.496,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2448479438491826 (199.004% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1024635398162824 (81.9923% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.08877000018936329 (14.3213% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 70.7957%)
#     iteration    4: trace = 0.08663610216033947 (2.43309% change)
#     iteration    5: trace = 0.08610584099782294 (0.613934% change)
#     iteration    6: trace = 0.08603569508602078 (0.081498% change)
#     iteration    7: trace = 0.08601740625201089 (0.0212595% change)
#     iteration    8: trace = 0.08601553102128232 (0.00218008% change)
#     iteration    9: trace = 0.08601488905681032 (0.000746338% change)
#     iteration   10: trace = 0.08601473517980854 (0.000178896% change)
#     iteration   11: trace = 0.08601470873307462 (3.07468e-05% change)
#     iteration   12: trace = 0.08601470045771498 (9.62087e-06% change)
# Finished solving for bands 1 to 2 after 12 iterations.
# tefreqs:, 1, -0.996, -0.496, 0, 0.996003, 0.182308, 0.229736
# elapsed time for k point: 0.025281429290771484
# Fixing h-field (band 1) phase by -0.581987 + -0.813198i; max ampl. = 1.46225
# Fixing h-field (band 2) phase by 0.747187 + -0.664613i; max ampl. = 1.69644
# total elapsed time for run: 0.061567068099975586
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 3 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.988, -0.4960000000000001, 0.0>
# elapsed time for initialization: 0.021338701248168945
# solve_kpoint (-0.988,-0.496,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2447170668067081 (199.005% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1024806230572397 (81.934% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.08877863151340956 (14.3282% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 74.3945%)
#     iteration    4: trace = 0.08666397039001406 (2.41066% change)
#     iteration    5: trace = 0.08613564686366598 (0.611487% change)
#     iteration    6: trace = 0.08606451156931724 (0.0826193% change)
#     iteration    7: trace = 0.08604556965674956 (0.0220114% change)
#     iteration    8: trace = 0.08604348624120309 (0.00242132% change)
#     iteration    9: trace = 0.08604275047160492 (0.000855117% change)
#     iteration   10: trace = 0.08604258131176765 (0.0001966% change)
#     iteration   11: trace = 0.08604255263056752 (3.33337e-05% change)
#     iteration   12: trace = 0.08604254401793972 (1.00097e-05% change)
#     iteration   13: trace = 0.08604254293379981 (1.26e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.988, -0.496, 0, 0.988003, 0.182354, 0.229759
# elapsed time for k point: 0.023004531860351562
# Fixing h-field (band 1) phase by -0.65175 + -0.758434i; max ampl. = 1.46188
# Fixing h-field (band 2) phase by 0.798226 + -0.602358i; max ampl. = 1.694
# total elapsed time for run: 0.0497283935546875
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 4 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.988, -0.4920000000000001, 0.0>
# elapsed time for initialization: 0.026944398880004883
# solve_kpoint (-0.988,-0.492,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2442317295303802 (199.007% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1025234818011443 (81.7339% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.08880984004693174 (14.3348% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 77.1405%)
#     iteration    4: trace = 0.08667257408315132 (2.43587% change)
#     iteration    5: trace = 0.08613719984329558 (0.619611% change)
#     iteration    6: trace = 0.08606480490945349 (0.0840814% change)
#     iteration    7: trace = 0.08604562568610399 (0.0222871% change)
#     iteration    8: trace = 0.08604352587871483 (0.00244037% change)
#     iteration    9: trace = 0.08604277826728392 (0.00086888% change)
#     iteration   10: trace = 0.08604260707797615 (0.000198959% change)
#     iteration   11: trace = 0.08604257813343835 (3.36398e-05% change)
#     iteration   12: trace = 0.08604256943667699 (1.01075e-05% change)
#     iteration   13: trace = 0.08604256834529717 (1.26842e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.988, -0.492, 0, 0.988003, 0.182354, 0.22976
# elapsed time for k point: 0.028131961822509766
# Fixing h-field (band 1) phase by -0.586117 + -0.810226i; max ampl. = 1.46205
# Fixing h-field (band 2) phase by 0.649754 + -0.760145i; max ampl. = 1.70765
# total elapsed time for run: 0.06040048599243164
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 5 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.98, -0.4920000000000001, 0.0>
# elapsed time for initialization: 0.020041704177856445
# solve_kpoint (-0.98,-0.492,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2441832060466244 (199.007% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1025775810301388 (81.6734% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.08885238043832383 (14.3397% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 73.7542%)
#     iteration    4: trace = 0.08673075701833804 (2.41666% change)
#     iteration    5: trace = 0.08619589897720215 (0.618595% change)
#     iteration    6: trace = 0.08612184899300025 (0.0859459% change)
#     iteration    7: trace = 0.08610176544091618 (0.0233226% change)
#     iteration    8: trace = 0.08609939633123506 (0.00275156% change)
#     iteration    9: trace = 0.08609853371141848 (0.00100189% change)
#     iteration   10: trace = 0.0860983456884271 (0.000218381% change)
#     iteration   11: trace = 0.08609831441296728 (3.63253e-05% change)
#     iteration   12: trace = 0.0860983053623071 (1.0512e-05% change)
#     iteration   13: trace = 0.08609830424643532 (1.29604e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.98, -0.492, 0, 0.980003, 0.182447, 0.229807
# elapsed time for k point: 0.02473306655883789
# Fixing h-field (band 1) phase by -0.650892 + -0.75917i; max ampl. = 1.46143
# Fixing h-field (band 2) phase by 0.690825 + 0.723022i; max ampl. = 1.80256
# total elapsed time for run: 0.0472569465637207
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 6 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.98, -0.4880000000000001, 0.0>
# elapsed time for initialization: 0.018612146377563477
# solve_kpoint (-0.98,-0.488,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2437068785506359 (199.009% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1026199833697392 (81.4761% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.08888294584109653 (14.3466% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 72.5743%)
#     iteration    4: trace = 0.08673910850113146 (2.44142% change)
#     switching back to exact line minimization
#     iteration    5: trace = 0.08619732324481569 (0.626572% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.08612209793469632 (0.0873091% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 70.2065%)
#     iteration    7: trace = 0.08610180770420728 (0.0235626% change)
#     iteration    8: trace = 0.08609943715111713 (0.00275324% change)
#     iteration    9: trace = 0.08609856380207986 (0.00101435% change)
#     iteration   10: trace = 0.08609837368934128 (0.000220809% change)
#     iteration   11: trace = 0.08609834244765903 (3.6286e-05% change)
#     iteration   12: trace = 0.08609833341534678 (1.04907e-05% change)
#     iteration   13: trace = 0.08609833230206015 (1.29304e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.98, -0.488, 0, 0.980003, 0.182447, 0.229807
# elapsed time for k point: 0.023958921432495117
# Fixing h-field (band 1) phase by -0.589292 + -0.80792i; max ampl. = 1.46154
# Fixing h-field (band 2) phase by 0.469321 + 0.883028i; max ampl. = 1.79604
# total elapsed time for run: 0.04421877861022949
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 7 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.9720000000000001, -0.48800000000000016, 0.0>
# elapsed time for initialization: 0.04296708106994629
# solve_kpoint (-0.972,-0.488,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2437409148719694 (199.009% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1027108530078318 (81.414% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.08895924659867821 (14.3492% change)
#     linmin: converged after 3 iterations.
#     iteration    4: trace = 0.08682757801058757 (2.42529% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 74.1779%)
#     iteration    5: trace = 0.08627944307662203 (0.63329% change)
#     iteration    6: trace = 0.08620845553799603 (0.0823102% change)
#     iteration    7: trace = 0.08618639538028133 (0.0255926% change)
#     iteration    8: trace = 0.08618327185923144 (0.00362421% change)
#     iteration    9: trace = 0.08618221177504617 (0.00123004% change)
#     iteration   10: trace = 0.0861819867856157 (0.000261063% change)
#     iteration   11: trace = 0.08618194579504213 (4.75628e-05% change)
#     iteration   12: trace = 0.08618193572005339 (1.16904e-05% change)
#     iteration   13: trace = 0.08618193439990586 (1.53181e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.972, -0.488, 0, 0.972003, 0.182586, 0.229879
# elapsed time for k point: 0.023463964462280273
# Fixing h-field (band 1) phase by -0.65092 + -0.759146i; max ampl. = 1.46065
# Fixing h-field (band 2) phase by 0.667131 + 0.744941i; max ampl. = 1.79933
# total elapsed time for run: 0.06934475898742676
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 8 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.9720000000000001, -0.48400000000000015, 0.0>
# elapsed time for initialization: 0.020252466201782227
# solve_kpoint (-0.972,-0.484,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2432724503114488 (199.011% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1027528652841918 (81.2193% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.0889892760251552 (14.3564% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 74.4833%)
#     iteration    4: trace = 0.08683573433901989 (2.44964% change)
#     iteration    5: trace = 0.08628622396783431 (0.634825% change)
#     iteration    6: trace = 0.08620755988049264 (0.091208% change)
#     iteration    7: trace = 0.08618594128817481 (0.0250805% change)
#     iteration    8: trace = 0.08618322971413037 (0.00314624% change)
#     iteration    9: trace = 0.08618221810535984 (0.0011738% change)
#     iteration   10: trace = 0.08618200974052932 (0.000241773% change)
#     iteration   11: trace = 0.08618197577541975 (3.94109e-05% change)
#     switching back to exact line minimization
#     iteration   12: trace = 0.08618196621652713 (1.10915e-05% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 73.0252%)
#     iteration   13: trace = 0.08618196505452741 (1.34831e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.972, -0.484, 0, 0.972003, 0.182586, 0.229879
# elapsed time for k point: 0.03753376007080078
# Fixing h-field (band 1) phase by -0.592076 + -0.805882i; max ampl. = 1.46072
# Fixing h-field (band 2) phase by 0.567033 + 0.823695i; max ampl. = 1.80279
# total elapsed time for run: 0.06062483787536621
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 9 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.964, -0.4840000000000001, 0.0>
# elapsed time for initialization: 0.020212411880493164
# solve_kpoint (-0.964,-0.484,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2433890860423048 (199.01% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1028802711088324 (81.1558% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.08909921090051021 (14.3568% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 74.2321%)
#     iteration    4: trace = 0.08695447336983089 (2.43646% change)
#     switching back to exact line minimization
#     iteration    5: trace = 0.0864026719485296 (0.636606% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 75.2697%)
#     iteration    6: trace = 0.08632095988781441 (0.094616% change)
#     iteration    7: trace = 0.08629791779267496 (0.0266971% change)
#     iteration    8: trace = 0.08629482531419762 (0.00358356% change)
#     iteration    9: trace = 0.08629366821720139 (0.00134087% change)
#     iteration   10: trace = 0.08629344092357814 (0.000263396% change)
#     iteration   11: trace = 0.08629340473180729 (4.19404e-05% change)
#     iteration   12: trace = 0.08629339472810116 (1.15927e-05% change)
#     iteration   13: trace = 0.08629339350110199 (1.42189e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.964, -0.484, 0, 0.964003, 0.182771, 0.229974
# elapsed time for k point: 0.03506803512573242
# Fixing h-field (band 1) phase by -0.651388 + -0.758745i; max ampl. = 1.45958
# Fixing h-field (band 2) phase by 0.663283 + 0.748369i; max ampl. = 1.79794
# total elapsed time for run: 0.057919979095458984
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 10 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.964, -0.4800000000000001, 0.0>
# elapsed time for initialization: 0.01970362663269043
# solve_kpoint (-0.964,-0.48,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2429273622595138 (199.012% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1029219490314227 (80.9632% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.08912880441107709 (14.3641% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 70.7006%)
#     iteration    4: trace = 0.08696248839121484 (2.46045% change)
#     iteration    5: trace = 0.0864039150687621 (0.644385% change)
#     iteration    6: trace = 0.08632115858178266 (0.0958245% change)
#     iteration    7: trace = 0.0862979678789392 (0.0268692% change)
#     iteration    8: trace = 0.08629486680666412 (0.00359351% change)
#     iteration    9: trace = 0.08629370188771657 (0.00134994% change)
#     iteration   10: trace = 0.08629347452742775 (0.000263473% change)
#     iteration   11: trace = 0.08629343806413356 (4.2255e-05% change)
#     iteration   12: trace = 0.08629342804589613 (1.16095e-05% change)
#     iteration   13: trace = 0.08629342683337951 (1.40511e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.964, -0.48, 0, 0.964003, 0.182771, 0.229974
# elapsed time for k point: 0.025206327438354492
# Fixing h-field (band 1) phase by -0.594653 + -0.803983i; max ampl. = 1.45962
# Fixing h-field (band 2) phase by 0.589278 + 0.80793i; max ampl. = 1.80083
# total elapsed time for run: 0.04739880561828613
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 11 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.956, -0.4800000000000001, 0.0>
# elapsed time for initialization: 0.030953168869018555
# solve_kpoint (-0.956,-0.48,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2431264772192214 (199.011% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1030856624397919 (80.8988% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.08927226599295428 (14.3622% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 62.5302%)
#     iteration    4: trace = 0.08711149041248514 (2.45008% change)
#     iteration    5: trace = 0.08654922278812988 (0.647547% change)
#     iteration    6: trace = 0.08646267416512196 (0.100049% change)
#     iteration    7: trace = 0.08643778938896923 (0.0287851% change)
#     iteration    8: trace = 0.0864342437789157 (0.00410201% change)
#     iteration    9: trace = 0.08643292346581141 (0.00152755% change)
#     iteration   10: trace = 0.086432678441427 (0.000283485% change)
#     iteration   11: trace = 0.08643263962022411 (4.4915e-05% change)
#     iteration   12: trace = 0.08643262917549881 (1.20842e-05% change)
#     iteration   13: trace = 0.08643262790485436 (1.4701e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.956, -0.48, 0, 0.956003, 0.183002, 0.230093
# elapsed time for k point: 0.022739171981811523
# Fixing h-field (band 1) phase by -0.652283 + -0.757976i; max ampl. = 1.4582
# Fixing h-field (band 2) phase by 0.662669 + 0.748912i; max ampl. = 1.79695
# total elapsed time for run: 0.05585932731628418
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 12 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.956, -0.4760000000000001, 0.0>
# elapsed time for initialization: 0.017423391342163086
# solve_kpoint (-0.956,-0.476,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2426703938199946 (199.013% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1031270498953837 (80.7081% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.08930151664718082 (14.3695% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 74.2466%)
#     iteration    4: trace = 0.08711941517114655 (2.47374% change)
#     iteration    5: trace = 0.08655041033708469 (0.655272% change)
#     iteration    6: trace = 0.0864628584245633 (0.101208% change)
#     iteration    7: trace = 0.08643783991319162 (0.0289397% change)
#     iteration    8: trace = 0.08643429140005635 (0.00410536% change)
#     iteration    9: trace = 0.08643296122850591 (0.00153895% change)
#     iteration   10: trace = 0.08643271466695168 (0.000285264% change)
#     iteration   11: trace = 0.08643267565671758 (4.51337e-05% change)
#     iteration   12: trace = 0.0864326651396604 (1.21679e-05% change)
#     iteration   13: trace = 0.08643266386340534 (1.47659e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.956, -0.476, 0, 0.956003, 0.183002, 0.230094
# elapsed time for k point: 0.024873971939086914
# Fixing h-field (band 1) phase by -0.597131 + -0.802144i; max ampl. = 1.45823
# Fixing h-field (band 2) phase by 0.599931 + 0.800052i; max ampl. = 1.79925
# total elapsed time for run: 0.04506802558898926
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 13 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.948, -0.4760000000000001, 0.0>
# elapsed time for initialization: 0.016405582427978516
# solve_kpoint (-0.948,-0.476,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.242951713769853 (199.012% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1033268416143526 (80.6431% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.08947841254340795 (14.3652% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 76.0741%)
#     iteration    4: trace = 0.08729868374069637 (2.46608% change)
#     iteration    5: trace = 0.08672457115786397 (0.659811% change)
#     iteration    6: trace = 0.08663243182094457 (0.1063% change)
#     iteration    7: trace = 0.08660543225178005 (0.0311705% change)
#     iteration    8: trace = 0.08660138181117105 (0.004677% change)
#     iteration    9: trace = 0.08659988729893628 (0.00172575% change)
#     iteration   10: trace = 0.08659962289213749 (0.00030532% change)
#     iteration   11: trace = 0.0865995814368344 (4.78701e-05% change)
#     iteration   12: trace = 0.08659957044161753 (1.26966e-05% change)
#     iteration   13: trace = 0.08659956909169893 (1.55881e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.948, -0.476, 0, 0.948003, 0.183278, 0.230236
# elapsed time for k point: 0.022344112396240234
# Fixing h-field (band 1) phase by -0.653464 + -0.756957i; max ampl. = 1.45651
# Fixing h-field (band 2) phase by 0.66312 + 0.748513i; max ampl. = 1.79601
# total elapsed time for run: 0.04203224182128906
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 14 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.948, -0.4720000000000001, 0.0>
# elapsed time for initialization: 0.019469261169433594
# solve_kpoint (-0.948,-0.472,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2425001892330848 (199.014% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1033679693665802 (80.4539% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.0895074063318409 (14.3726% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 70.4531%)
#     iteration    4: trace = 0.0873065667957898 (2.48944% change)
#     iteration    5: trace = 0.08672572487131402 (0.667511% change)
#     iteration    6: trace = 0.08663261293917741 (0.107421% change)
#     iteration    7: trace = 0.08660549094797697 (0.0313118% change)
#     iteration    8: trace = 0.0866014345817116 (0.00468384% change)
#     iteration    9: trace = 0.08659992790473248 (0.0017398% change)
#     iteration   10: trace = 0.08659966175624863 (0.000307332% change)
#     iteration   11: trace = 0.08659962008733971 (4.81167e-05% change)
#     iteration   12: trace = 0.08659960901609673 (1.27844e-05% change)
#     iteration   13: trace = 0.08659960766055289 (1.5653e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.948, -0.472, 0, 0.948003, 0.183278, 0.230236
# elapsed time for k point: 0.022077083587646484
# Fixing h-field (band 1) phase by -0.599575 + -0.800318i; max ampl. = 1.45653
# Fixing h-field (band 2) phase by 0.606696 + 0.794934i; max ampl. = 1.79789
# total elapsed time for run: 0.04350709915161133
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 15 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.94, -0.4720000000000001, 0.0>
# elapsed time for initialization: 0.02207779884338379
# solve_kpoint (-0.94,-0.472,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2428632905525542 (199.012% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1036036025169422 (80.3885% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.08971765501944441 (14.3657% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 62.2761%)
#     iteration    4: trace = 0.08751611520684738 (2.48433% change)
#     iteration    5: trace = 0.08692873507284143 (0.673428% change)
#     iteration    6: trace = 0.0868301794296784 (0.11344% change)
#     iteration    7: trace = 0.08680077094121683 (0.0338747% change)
#     iteration    8: trace = 0.08679615422116432 (0.0053189% change)
#     iteration    9: trace = 0.08679447474498204 (0.00193498% change)
#     iteration   10: trace = 0.08679419032074193 (0.000327699% change)
#     iteration   11: trace = 0.08679414605493134 (5.10009e-05% change)
#     iteration   12: trace = 0.0867941344395137 (1.33827e-05% change)
#     iteration   13: trace = 0.08679413299281269 (1.66682e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.94, -0.472, 0, 0.940003, 0.183599, 0.230403
# elapsed time for k point: 0.02129673957824707
# Fixing h-field (band 1) phase by -0.654887 + -0.755727i; max ampl. = 1.45452
# Fixing h-field (band 2) phase by 0.664097 + 0.747647i; max ampl. = 1.79503
# total elapsed time for run: 0.04625225067138672
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 16 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.94, -0.4680000000000001, 0.0>
# elapsed time for initialization: 0.01520538330078125
# solve_kpoint (-0.94,-0.468,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.2424152593959316 (199.014% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 0.1036444867592559 (80.2005% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 0.08974647060570437 (14.373% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 62.3201%)
#     iteration    4: trace = 0.08752400285579227 (2.50743% change)
#     iteration    5: trace = 0.08692987579589934 (0.681128% change)
#     iteration    6: trace = 0.08683036606088401 (0.114537% change)
#     iteration    7: trace = 0.08680084090637838 (0.034009% change)
#     iteration    8: trace = 0.08679621279860375 (0.00533201% change)
#     iteration    9: trace = 0.08679451821352169 (0.00195239% change)
#     iteration   10: trace = 0.08679423181348005 (0.000329975% change)
#     iteration   11: trace = 0.08679418730625783 (5.1279e-05% change)
#     iteration   12: trace = 0.08679417561035449 (1.34754e-05% change)
#     iteration   13: trace = 0.0867941741577761 (1.67359e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.94, -0.468, 0, 0.940003, 0.183599, 0.230403
# elapsed time for k point: 0.05761981010437012
# Fixing h-field (band 1) phase by -0.60203 + -0.798473i; max ampl. = 1.45452
# Fixing h-field (band 2) phase by 0.61171 + 0.791082i; max ampl. = 1.79661
# total elapsed time for run: 0.07637953758239746
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 17 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.9319999999999999, -0.4680000000000001, 0.0>
# elapsed time for initialization: 0.01810741424560547
# solve_kpoint (-0.932,-0.468,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.424464194745432 (198.108% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.1205964181945785 (111.499% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 0.09595516153272345 (22.7579% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 0.08870162103271798 (7.85624% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 63.2682%)
#     iteration    5: trace = 0.0873626751258247 (1.52097% change)
#     iteration    6: trace = 0.08711928608900457 (0.278985% change)
#     iteration    7: trace = 0.08703807892876028 (0.0932572% change)
#     iteration    8: trace = 0.08702244312775204 (0.0179659% change)
#     iteration    9: trace = 0.08701744191925975 (0.0057472% change)
#     iteration   10: trace = 0.0870164338360546 (0.00115849% change)
#     iteration   11: trace = 0.08701626125282166 (0.000198334% change)
#     iteration   12: trace = 0.08701622337884447 (4.35252e-05% change)
#     iteration   13: trace = 0.08701621925177924 (4.74287e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, -0.932, -0.468, 0, 0.932003, 0.183965, 0.230593
# elapsed time for k point: 0.02411651611328125
# Fixing h-field (band 1) phase by -0.517087 + 0.855933i; max ampl. = 1.45213
# Fixing h-field (band 2) phase by 0.646407 + 0.762992i; max ampl. = 1.79401
# total elapsed time for run: 0.044353485107421875
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 18 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<-0.9319999999999999, -0.4640000000000001, 0.0>
# elapsed time for initialization: 0.015158653259277344
# solve_kpoint (-0.932,-0.464,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.4251736775275042 (198.105% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.1198044253717546 (112.067% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 0.09559610009339749 (22.4775% change)
#     linmin: converged after 5 iterations.
#     iteration    4: trace = 0.08861146967161278 (7.58343% change)
#     linmin: converged after 3 iterations.
# ...
#     iteration    1: trace = 0.4404171704017663 (198.102% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.1148035185645432 (117.292% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 0.09319031237442159 (20.7825% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.08719694411669773 (6.645% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 75.0933%)
#     iteration    5: trace = 0.08623664933831504 (1.10739% change)
#     switching back to exact line minimization
#     iteration    6: trace = 0.08609694565494075 (0.162132% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.08605681919029941 (0.046617% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.08605107414885965 (0.00667609% change)
#     linmin: converged after 2 iterations.
#     iteration    9: trace = 0.086049606211024 (0.00170591% change)
#     linmin: converged after 2 iterations.
#     iteration   10: trace = 0.08604920936412432 (0.000461185% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 83.3541%)
#     iteration   11: trace = 0.08604913313128265 (8.85922e-05% change)
#     iteration   12: trace = 0.08604911239020489 (2.41038e-05% change)
#     iteration   13: trace = 0.08604910954128719 (3.3108e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, 0.988, 0.492, 0, 0.988003, 0.182352, 0.229775
# elapsed time for k point: 0.028217792510986328
# Fixing h-field (band 1) phase by 0.886423 + -0.462875i; max ampl. = 1.46261
# Fixing h-field (band 2) phase by 0.464284 + -0.885686i; max ampl. = 1.7069
# total elapsed time for run: 0.05483126640319824
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 498 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.988, 0.4960000000000001, 0.0>
# elapsed time for initialization: 0.02429366111755371
# solve_kpoint (0.988,0.496,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.439720953636703 (198.105% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.1155714638980055 (116.749% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 0.09346961445249614 (21.1459% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.08724444305963767 (6.88953% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 74.9762%)
#     iteration    5: trace = 0.08624792768217121 (1.14877% change)
#     iteration    6: trace = 0.08609973355533847 (0.171971% change)
#     iteration    7: trace = 0.08605742292213719 (0.0491535% change)
#     iteration    8: trace = 0.08605128510073956 (0.00713249% change)
#     iteration    9: trace = 0.08604966460056682 (0.0018832% change)
#     iteration   10: trace = 0.08604924361103058 (0.000489241% change)
#     iteration   11: trace = 0.08604916061965978 (9.64464e-05% change)
#     iteration   12: trace = 0.08604913841978594 (2.57991e-05% change)
#     iteration   13: trace = 0.08604913542013104 (3.48598e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, 0.988, 0.496, 0, 0.988003, 0.182352, 0.229775
# elapsed time for k point: 0.0342409610748291
# Fixing h-field (band 1) phase by 0.921436 + -0.388529i; max ampl. = 1.46242
# Fixing h-field (band 2) phase by 0.244624 + -0.969618i; max ampl. = 1.69519
# total elapsed time for run: 0.06298661231994629
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 499 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.996, 0.4960000000000001, 0.0>
# elapsed time for initialization: 0.023595571517944336
# solve_kpoint (0.996,0.496,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.4392124392281963 (198.107% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.1145229299904241 (117.272% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 0.09310112144660466 (20.6352% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.087152843885587 (6.59989% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 75.5518%)
#     iteration    5: trace = 0.08620424602632831 (1.09439% change)
#     iteration    6: trace = 0.08606752430183053 (0.158728% change)
#     iteration    7: trace = 0.08602850883477899 (0.0453415% change)
#     iteration    8: trace = 0.08602304807993404 (0.00634781% change)
#     iteration    9: trace = 0.08602164732380319 (0.00162836% change)
#     iteration   10: trace = 0.08602127978486253 (0.000427264% change)
#     iteration   11: trace = 0.08602120644390697 (8.52591e-05% change)
#     iteration   12: trace = 0.08602118634015488 (2.33707e-05% change)
#     iteration   13: trace = 0.08602118355647599 (3.23604e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, 0.996, 0.496, 0, 0.996003, 0.182306, 0.229751
# elapsed time for k point: 0.02656865119934082
# Fixing h-field (band 1) phase by 0.88288 + -0.469598i; max ampl. = 1.46281
# Fixing h-field (band 2) phase by 0.339124 + -0.940742i; max ampl. = 1.69616
# total elapsed time for run: 0.05204200744628906
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 500 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<0.996, 0.5000000000000001, 0.0>
# elapsed time for initialization: 0.026799917221069336
# solve_kpoint (0.996,0.5,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.438532064012173 (198.11% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.1152881019992343 (116.732% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 0.09338009846357009 (20.9979% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.08719995360306221 (6.84477% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 69.7248%)
#     iteration    5: trace = 0.08621539921237462 (1.13549% change)
#     switching back to exact line minimization
#     iteration    6: trace = 0.08607027740712828 (0.168466% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 70.1661%)
#     iteration    7: trace = 0.08602909853875985 (0.0478548% change)
#     iteration    8: trace = 0.08602320676778108 (0.00684881% change)
#     iteration    9: trace = 0.08602171699146925 (0.00173185% change)
#     iteration   10: trace = 0.08602131279586639 (0.000469877% change)
#     iteration   11: trace = 0.08602123634634935 (8.88728e-05% change)
#     iteration   12: trace = 0.08602121506196572 (2.47432e-05% change)
#     iteration   13: trace = 0.08602121218025381 (3.35e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, 0.996, 0.5, 0, 0.996003, 0.182306, 0.229752
# elapsed time for k point: 0.03693985939025879
# Fixing h-field (band 1) phase by 0.921525 + -0.38832i; max ampl. = 1.4625
# Fixing h-field (band 2) phase by 0.293034 + -0.956102i; max ampl. = 1.68996
# total elapsed time for run: 0.06636309623718262
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 501 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<1.004, 0.5000000000000001, 0.0>
# elapsed time for initialization: 0.02782607078552246
# solve_kpoint (1.004,0.5,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.4380041346874969 (198.113% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.114302261356907 (117.218% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 0.09305748653264206 (20.4907% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.08714289787976971 (6.56446% change)
#     linmin: converged after 3 iterations.
#     iteration    5: trace = 0.08620241235268156 (1.0851% change)
#     linmin: converged after 4 iterations.
#     iteration    6: trace = 0.08606694888015468 (0.157269% change)
#     linmin: converged after 4 iterations.
#     iteration    7: trace = 0.08602805774127116 (0.0451973% change)
#     linmin: converged after 2 iterations.
#     iteration    8: trace = 0.08602303307282932 (0.0058409% change)
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 76.618%)
#     iteration    9: trace = 0.08602160673266196 (0.0016581% change)
#     iteration   10: trace = 0.08602125974757542 (0.000403371% change)
#     iteration   11: trace = 0.08602118754157989 (8.39397e-05% change)
#     iteration   12: trace = 0.08602116799065776 (2.2728e-05% change)
#     iteration   13: trace = 0.08602116534522 (3.07533e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, 1.004, 0.5, 0, 1.004, 0.182306, 0.229751
# elapsed time for k point: 0.03507518768310547
# Fixing h-field (band 1) phase by 0.878211 + -0.478273i; max ampl. = 1.46265
# Fixing h-field (band 2) phase by 0.311923 + -0.950107i; max ampl. = 1.69357
# total elapsed time for run: 0.06730365753173828
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Calculating 502 of 252.0 ...
# Initializing eigensolver data
# Computing 2 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 2 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0.5, 0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0.57735, 0)
#      (-0, 1.1547, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (0.333333,0.333333,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 2 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 1 k-points
#   Vector3<1.004, 0.5040000000000001, 0.0>
# elapsed time for initialization: 0.023585081100463867
# solve_kpoint (1.004,0.504,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2
# Solving for bands 1 to 2...
#     near maximum in trace
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 0.4373356911946136 (198.115% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 0.1150644102424937 (116.68% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 0.0933367287160675 (20.8518% change)
#     linmin: converged after 4 iterations.
#     iteration    4: trace = 0.08718995759339732 (6.80982% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 74.2053%)
#     iteration    5: trace = 0.0862136102573185 (1.1261% change)
#     iteration    6: trace = 0.08606981501969588 (0.166929% change)
#     iteration    7: trace = 0.0860289910677771 (0.0474425% change)
#     iteration    8: trace = 0.08602319779486972 (0.00673432% change)
#     iteration    9: trace = 0.08602169125594959 (0.00175133% change)
#     iteration   10: trace = 0.08602129885251797 (0.000456169% change)
#     iteration   11: trace = 0.08602122084147459 (9.06881e-05% change)
#     iteration   12: trace = 0.08602119966713093 (2.46153e-05% change)
#     iteration   13: trace = 0.08602119677206167 (3.36553e-06% change)
# Finished solving for bands 1 to 2 after 13 iterations.
# tefreqs:, 1, 1.004, 0.504, 0, 1.004, 0.182306, 0.229752
# elapsed time for k point: 0.02411484718322754
# Fixing h-field (band 1) phase by 0.923328 + -0.384011i; max ampl. = 1.46203
# Fixing h-field (band 2) phase by 0.299347 + -0.954144i; max ampl. = 1.68905
# total elapsed time for run: 0.0502619743347168
# done
# mu: 1-1, mean 1, harm. mean 1, 0% > 1, 100% "fill"
# epsilon: 1-12, mean 9.35354, harm. mean 3.56975, 80.4688% > 1, 75.9413% "fill"
# Elapsed: 35.96018385887146

# %%
fig,ax=plt.subplots(1,2,figsize=(15,5))
ax[0].plot(fields_cur[:, 0]*(2*np.pi)**2)
ax[0].set_ylabel('berry curvature for band1')
ax[1].plot(fields_cur[:, 1]*(2*np.pi)**2)
ax[1].set_ylabel('berry curvature for band2')
# Out:
# Text(0, 0.5, 'berry curvature for band2')

# %%
fig,ax=plt.subplots(1,2,figsize=(15,5))
ax[0].plot(fields_cur[:, 0]*(2*np.pi)**2)
ax[0].set_ylabel('berry curvature')
ax[1].plot(np.imag(neiji[:, 0]))
ax[1].set_ylabel('dot product before log')
# Out:
# Text(0, 0.5, 'dot product before log')
