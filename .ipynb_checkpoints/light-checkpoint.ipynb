# %% [markdown]
# #Z型结构

# %%
import math
import meep as mp
import numpy as np
from meep import mpb
import matplotlib.pyplot as plt

resolution = 10   # pixels/um
eps = 2          # dielectric constant of waveguide
w = 20        # width of waveguide
r1 = 181/385/2
r2 = 81/385/2
d = 1.4           # defect spacing (ordinary spacing = 1)
sy = 30     # size of cell in y direction (perpendicular to wvg.)
pad = 2           # padding between last hole and PML edge
dpml = 1          # PML thickness
sx =30 # size of cell in x direction
cell = mp.Vector3(sx,sy,0)#计算单元
nSi = 3.47
Si = mp.Medium(index=nSi)
blk = mp.Block(size=mp.Vector3(16,14,mp.inf), center=mp.Vector3(0,0,0),
               material=Si)
geometry = [blk]
a = 1/math.sqrt(3)
b = 1/2
c = 3*a/2
geometry.append(mp.Block(size=mp.Vector3(12,4,mp.inf), center=mp.Vector3(-12.5,-4*a,0),
               material=Si))
geometry.append(mp.Block(size=mp.Vector3(12,4,mp.inf), center=mp.Vector3(12.5,6*a,0),
               material=Si))

#colomn 1 btm
for i in range(6):
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i,-6*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i, -7*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i, -9*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i, -10*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i, -12*a), material=mp.air))

    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i, -4*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i, -3*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i, -a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i, 0), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i, 2*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i, 3*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i, 5*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i, 6*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i, 8*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i, 9*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i, 11*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i, 12*a), material=mp.air))


    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i+b,c-6*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i+b, c-7*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i+b, c-9*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i+b, c-10*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i+b, c-12*a), material=mp.air))

    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i+b, c-4*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i+b, c-3*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i+b, c-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i+b, c+0), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i+b, c+2*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i+b, c+3*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i+b, c+5*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i+b, c+6*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i+b, c+8*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i+b, c+9*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8+i+b, c+11*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8+i+b, c+12*a), material=mp.air))
    
    
for i in range(6):
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i,6*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i,7*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i,9*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i,10*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i,12*a-a), material=mp.air))
    
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i,4*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i,3*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i,a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i, 0-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i, -2*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i, -3*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i, -5*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i, -6*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i, -8*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i, -9*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i, -11*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i, -12*a-a), material=mp.air))


    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i+b,c+6*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i+b,c+7*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i+b,c+9*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i+b,c+10*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i+b,c+12*a-a), material=mp.air))

    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i+b,c+4*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i+b,c+3*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i+b,c+a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i+b,c+0-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i+b,c-2*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i+b,c-3*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i+b,c-5*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i+b,c-6*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i+b,c-8*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i+b,c-9*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+i+b, c-11*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+i+b, c-12*a-a), material=mp.air))

    
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6,6*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6,7*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6,9*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6,10*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6,12*a-a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6,4*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6,3*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6,a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6, 0-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6, -2*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6, -3*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6, -5*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6, -6*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6, -8*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6, -9*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6, -11*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6, -12*a-a), material=mp.air))
    
    

##1
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2,-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-2, -7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2, -9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-2, -10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2, -12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2, -4*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-2, -3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2, -a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-2, 0), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2, 2*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-2, 3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2, 5*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2, 6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2, 8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-2, 9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2, 11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-2, 12*a), material=mp.air))


geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2+b,c-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-2+b, c-7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2+b, c-9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-2+b, c-10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2+b, c-12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2+b, c-4*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-2+b, c-3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2+b, c-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-2+b, c+0), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2+b, c+2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2+b, c+3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2+b, c+5*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-2+b, c+6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2+b, c+8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-2+b, c+9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-2+b, c+11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-2+b, c+12*a), material=mp.air))    
    

##2
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1,-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-1, -7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1, -9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-1, -10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1, -12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1, -4*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-1, -3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1, -a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-1, 0), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1, 2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1, 3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-1, 5*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1, 6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1, 8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-1, 9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1, 11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-1, 12*a), material=mp.air))


geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1+b,c-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-1+b, c-7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1+b, c-9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-1+b, c-10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1+b, c-12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1+b, c-4*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-1+b, c-3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1+b, c-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1+b, c+0), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-1+b, c+2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1+b, c+3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1+b, c+5*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-1+b, c+6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1+b, c+8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-1+b, c+9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-1+b, c+11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-1+b, c+12*a), material=mp.air)) 



##3
geometry.append(mp.Cylinder(r1, center=mp.Vector3(0,-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(0, -7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(0, -9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(0, -10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(0, -12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(0, -4*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(0, -3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(0, -a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(0, 0), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(0, 2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(0, 3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(0, 5*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(0, 6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(0, 8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(0, 9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(0, 11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(0, 12*a), material=mp.air))


geometry.append(mp.Cylinder(r1, center=mp.Vector3(b,c-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(b, c-7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b, c-9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(b, c-10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b, c-12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(b, c-4*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b, c-3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(b, c-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b, c+0), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(b, c+2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b, c+3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b, c+5*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(b, c+6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b, c+8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(b, c+9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b, c+11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(b, c+12*a), material=mp.air)) 


##4
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1,-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(1, -7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1, -9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(1, -10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1, -12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(1, -4*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1, -3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(1, -a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1, 0), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(1, 2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1, 3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(1, 5*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1, 6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1, 8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(1, 9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1, 11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(1, 12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(1+b,c-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(1+b, c-7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1+b, c-9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(1+b, c-10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1+b, c-12*a), material=mp.air))

geometry.append(mp.Cylinder(r2, center=mp.Vector3(1+b, c-4*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1+b, c-3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(1+b, c-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1+b, c+0), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(1+b, c+2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1+b, c+3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1+b, c+5*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(1+b, c+6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1+b, c+8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(1+b, c+9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(1+b, c+11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(1+b, c+12*a), material=mp.air)) 


pml_layers = [mp.PML(1.0)]
fsrc = 0.7
kx = 1    # initial guess for wavevector in x-direction of eigenmode
k_points = mp.Vector3(0, 1/2)

fsrc =2/1.430
sources = [mp.EigenModeSource(src=mp.ContinuousSource(fsrc),
                               direction=mp.X,
                               component=mp.Ez,
                                amplitude=1,
                                center=mp.Vector3(-10,0,0),
                                size=mp.Vector3(0,5,0),
                              eig_band=1,
                               eig_kpoint=k_points,
                                eig_parity=mp.ODD_Y,
                               eig_match_freq=True)]
sim = mp.Simulation(cell_size=cell,
                    resolution=resolution,
                    boundary_layers=pml_layers,
                    sources=sources,
                    geometry=geometry
                   )
sim.run(until=200)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0438719 s
# Working in 2D dimensions.
# Computational cell is 30 x 30 x 0 with resolution 10
#      block, center = (0,0,0)
#           size (16,14,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.0409,12.0409,12.0409)
#      block, center = (-12.5,-2.3094,0)
#           size (12,4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.0409,12.0409,12.0409)
#      block, center = (12.5,3.4641,0)
#           size (12,4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.0409,12.0409,12.0409)
#      cylinder, center = (-8,-3.4641,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-8,-4.04145,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
eps_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
plt.figure()
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()
ez_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
plt.figure()
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

# %%
plt.figure(dpi=100)
sim.plot2D(fields=mp.Ez)
plt.show()

# %% [markdown]
# #Ω型结构

# %%
import math
import meep as mp
import numpy as np
from meep import mpb
import matplotlib.pyplot as plt

resolution = 10   # pixels/um
eps = 2          # dielectric constant of waveguide
w = 20        # width of waveguide
r1 = 181/385/2
r2 = 81/385/2
d = 1.4           # defect spacing (ordinary spacing = 1)
sy = 30     # size of cell in y direction (perpendicular to wvg.)
pad = 2           # padding between last hole and PML edge
dpml = 1          # PML thickness
sx =30 # size of cell in x direction
cell = mp.Vector3(sx,sy,0)#计算单元
nSi = 3.47
Si = mp.Medium(index=nSi)
blk = mp.Block(size=mp.Vector3(16,14,mp.inf), center=mp.Vector3(0,0,0),
               material=Si)
geometry = [blk]
a = 1/math.sqrt(3)
b = 1/2
c = 3*a/2
geometry.append(mp.Block(size=mp.Vector3(12,4,mp.inf), center=mp.Vector3(-12.5,6*a,0),
               material=Si))
geometry.append(mp.Block(size=mp.Vector3(12,4,mp.inf), center=mp.Vector3(12.5,6*a,0),
               material=Si))

#colomn 1 btm
for i in range(3):
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0+i,-6*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0+i, -7*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0+i, -9*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0+i, -10*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0+i, -12*a), material=mp.air))

    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0+i, -4*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0+i, -3*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0+i, -a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0+i, 0), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0+i, 2*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0+i, 3*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0+i, 5*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0+i, 6*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0+i, 8*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0+i, 9*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0+i, 11*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0+i, 12*a), material=mp.air))


    geometry.append(mp.Cylinder(r1, center=mp.Vector3(i+b,c-6*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(i+b, c-7*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(i+b, c-9*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(i+b, c-10*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(i+b, c-12*a), material=mp.air))

    geometry.append(mp.Cylinder(r1, center=mp.Vector3(i+b, c-4*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(i+b, c-3*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(i+b, c-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(i+b, c+0), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(i+b, c+2*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(i+b, c+3*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(i+b, c+5*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(i+b, c+6*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(i+b, c+8*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(i+b, c+9*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(i+b, c+11*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(i+b, c+12*a), material=mp.air))
    
    
    
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0-i,-6*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0-i, -7*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0-i, -9*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0-i, -10*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0-i, -12*a), material=mp.air))
    
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0-i, -4*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0-i, -3*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0-i, -a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0-i, 0), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0-i, 2*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0-i, 3*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0-i, 5*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0-i, 6*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0-i, 8*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0-i, 9*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(0-i, 11*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(0-i, 12*a), material=mp.air))


    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(i+b),c-6*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-(i+b), c-7*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(i+b), c-9*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-(i+b), c-10*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(i+b), c-12*a), material=mp.air))

    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(i+b), c-4*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-(i+b), c-3*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(i+b), c-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-(i+b), c+0), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(i+b), c+2*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-(i+b), c+3*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(i+b), c+5*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-(i+b), c+6*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(i+b), c+8*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-(i+b), c+9*a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(i+b), c+11*a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-(i+b), c+12*a), material=mp.air))
    

for i in range(2):
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i,6*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i,7*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i,9*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i,10*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i,12*a-a), material=mp.air))

    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i,4*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i,3*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i,a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i, 0-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i, -2*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i, -3*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i, -5*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i, -6*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i, -8*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i, -9*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i, -11*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i, -12*a-a), material=mp.air))


    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i+b,c+6*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i+b,c+7*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i+b,c+9*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i+b,c+10*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i+b,c+12*a-a), material=mp.air))

    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i+b,c+4*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i+b,c+3*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i+b,c+a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i+b,c+0-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i+b,c-2*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i+b,c-3*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i+b,c-5*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i+b,c-6*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i+b,c-8*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i+b,c-9*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+i+b, c-11*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+i+b, c-12*a-a), material=mp.air))
    
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i,6*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i,7*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i,9*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i,10*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i,12*a-a), material=mp.air))
    
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i,4*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i,3*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i,a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i, 0-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i, -2*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i, -3*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i, -5*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i, -6*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i, -8*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i, -9*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i, -11*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i, -12*a-a), material=mp.air))


    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i-b,c+6*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i-b,c+7*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i-b,c+9*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i-b,c+10*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i-b,c+12*a-a), material=mp.air))

    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i-b,c+4*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i-b,c+3*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i-b,c+a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i-b,c+0-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i-b,c-2*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i-b,c-3*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i-b,c-5*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i-b,c-6*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i-b,c-8*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i-b,c-9*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-i-b, c-11*a-a), material=mp.air))
    geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-i-b, c-12*a-a), material=mp.air))
    
    
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6,6*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6,7*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6,9*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6,10*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6,12*a-a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6,4*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6,3*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6,a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6, 0-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6, -2*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6, -3*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6, -5*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6, -6*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6, -8*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6, -9*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(2+6, -11*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(2+6, -12*a-a), material=mp.air))

geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8,6*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8,7*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8,9*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8,10*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8,12*a-a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8,4*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8,3*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8,a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8, 0-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8, -2*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8, -3*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8, -5*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8, -6*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8, -8*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8, -9*a-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-8, -11*a-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-8, -12*a-a), material=mp.air))



##右1
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3,-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(3, -7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3, -9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(3, -10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3, -12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(3, -4*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(3, -3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3, -a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(3, 0), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3, 2*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(3, 3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3, 5*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3, 6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3, 8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(3, 9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3, 11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(3, 12*a), material=mp.air))


geometry.append(mp.Cylinder(r1, center=mp.Vector3(3+b,c-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(3+b, c-7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3+b, c-9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(3+b, c-10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3+b, c-12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(3+b, c-4*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(3+b, c-3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3+b, c-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(3+b, c+0), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3+b, c+2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3+b, c+3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3+b, c+5*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(3+b, c+6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3+b, c+8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(3+b, c+9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(3+b, c+11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(3+b, c+12*a), material=mp.air))    
    


##右2
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4,-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(4, -7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4, -9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(4, -10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4, -12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(4, -4*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(4, -3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4, -a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(4, 0), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4, 2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4, 3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(4, 5*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4, 6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4, 8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(4, 9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4, 11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(4, 12*a), material=mp.air))


geometry.append(mp.Cylinder(r1, center=mp.Vector3(4+b,c-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(4+b, c-7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4+b, c-9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(4+b, c-10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4+b, c-12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(4+b, c-4*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(4+b, c-3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4+b, c-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4+b, c+0), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(4+b, c+2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4+b, c+3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4+b, c+5*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(4+b, c+6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4+b, c+8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(4+b, c+9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(4+b, c+11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(4+b, c+12*a), material=mp.air)) 



##右3
geometry.append(mp.Cylinder(r1, center=mp.Vector3(5,-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(5, -7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(5, -9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(5, -10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(5, -12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(5, -4*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(5, -3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(5, -a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(5, 0), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(5, 2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(5, 3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(5, 5*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(5, 6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(5, 8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(5, 9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(5, 11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(5, 12*a), material=mp.air))


geometry.append(mp.Cylinder(r1, center=mp.Vector3(b+5,c-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(b+5, c-7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b+5, c-9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(b+5, c-10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b+5, c-12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(b+5, c-4*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b+5, c-3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(b+5, c-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b+5, c+0), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(b+5, c+2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b+5, c+3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b+5, c+5*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(b+5, c+6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b+5, c+8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(b+5, c+9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(b+5, c+11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(b+5, c+12*a), material=mp.air)) 


##右4
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6,-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(6, -7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6, -9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(6, -10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6, -12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(6, -4*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6, -3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(6, -a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6, 0), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(6, 2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6, 3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(6, 5*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6, 6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6, 8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(6, 9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6, 11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(6, 12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+b,c-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+b, c-7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+b, c-9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+b, c-10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+b, c-12*a), material=mp.air))

geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+b, c-4*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+b, c-3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+b, c-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+b, c+0), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+b, c+2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+b, c+3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+b, c+5*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+b, c+6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+b, c+8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+b, c+9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(6+b, c+11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(6+b, c+12*a), material=mp.air)) 




##左1
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-3,-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-3, -7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-3, -9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-3, -10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-3, -12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(-3, -4*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-3, -3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-3, -a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-3, 0), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-3, 2*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-3, 3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-3, 5*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-3, 6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-3, 8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-3, 9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-3, 11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-3, 12*a), material=mp.air))


geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(3+b),c-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-(3+b), c-7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(3+b), c-9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-(3+b), c-10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(3+b), c-12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(3+b), c-4*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-(3+b), c-3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(3+b), c-a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-(3+b), c+0), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(3+b), c+2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(3+b), c+3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(3+b), c+5*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-(3+b), c+6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(3+b), c+8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-(3+b), c+9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-(3+b), c+11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-(3+b), c+12*a), material=mp.air))    
    


##左2
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4,-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-4, -7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4, -9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-4, -10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4, -12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4, -4*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-4, -3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4, -a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-4, 0), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4, 2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4, 3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-4, 5*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4, 6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4, 8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-4, 9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4, 11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-4, 12*a), material=mp.air))


geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4-b,c-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-4-b, c-7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4-b, c-9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-4-b, c-10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4-b, c-12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4-b, c-4*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-4-b, c-3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4-b, c-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4-b, c+0), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-4-b, c+2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4-b, c+3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4-b, c+5*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-4-b, c+6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4-b, c+8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-4-b, c+9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-4-b, c+11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-4-b, c+12*a), material=mp.air)) 



##左3
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-5,-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-5, -7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-5, -9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-5, -10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-5, -12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(-5, -4*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-5, -3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-5, -a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-5, 0), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-5, 2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-5, 3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-5, 5*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-5, 6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-5, 8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-5, 9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-5, 11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-5, 12*a), material=mp.air))


geometry.append(mp.Cylinder(r1, center=mp.Vector3(-b-5,c-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-b-5, c-7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-b-5, c-9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-b-5, c-10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-b-5, c-12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(-b-5, c-4*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-b-5, c-3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-b-5, c-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-b-5, c+0), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-b-5, c+2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-b-5, c+3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-b-5, c+5*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-b-5, c+6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-b-5, c+8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-b-5, c+9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-b-5, c+11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-b-5, c+12*a), material=mp.air)) 


##左4
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6,-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6, -7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6, -9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6, -10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6, -12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6, -4*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6, -3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6, -a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6, 0), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6, 2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6, 3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6, 5*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6, 6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6, 8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6, 9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6, 11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6, 12*a), material=mp.air))

geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-b,c-6*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-b, c-7*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-b, c-9*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-b, c-10*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-b, c-12*a), material=mp.air))

geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-b, c-4*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-b, c-3*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-b, c-a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-b, c+0), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-b, c+2*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-b, c+3*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-b, c+5*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-b, c+6*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-b, c+8*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-b, c+9*a), material=mp.air))
geometry.append(mp.Cylinder(r1, center=mp.Vector3(-6-b, c+11*a), material=mp.air))
geometry.append(mp.Cylinder(r2, center=mp.Vector3(-6-b, c+12*a), material=mp.air)) 


pml_layers = [mp.PML(1.0)]
fsrc = 0.7
kx = 1    # initial guess for wavevector in x-direction of eigenmode
k_points = mp.Vector3(0, 1/2)

fsrc =2/1.430
sources = [mp.EigenModeSource(src=mp.ContinuousSource(fsrc),
                               direction=mp.X,
                               component=mp.Ez,
                                amplitude=1,
                                center=mp.Vector3(-10,0,0),
                                size=mp.Vector3(0,5,0),
                              eig_band=1,
                               eig_kpoint=k_points,
                                eig_parity=mp.ODD_Y,
                               eig_match_freq=True)]
sim = mp.Simulation(cell_size=cell,
                    resolution=resolution,
                    boundary_layers=pml_layers,
                    sources=sources,
                    geometry=geometry
                   )
sim.run(until=200)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0252931 s
# Working in 2D dimensions.
# Computational cell is 30 x 30 x 0 with resolution 10
#      block, center = (0,0,0)
#           size (16,14,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.0409,12.0409,12.0409)
#      block, center = (-12.5,3.4641,0)
#           size (12,4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.0409,12.0409,12.0409)
#      block, center = (12.5,3.4641,0)
#           size (12,4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12.0409,12.0409,12.0409)
#      cylinder, center = (0,-3.4641,0)
#           radius 0.235065, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (0,-4.04145,0)
#           radius 0.105195, height 1e+20, axis (0, 0, 1)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
eps_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
plt.figure()
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()
ez_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
plt.figure()
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()
